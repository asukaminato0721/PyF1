# %% [markdown]
# # Examples

# %% [markdown]
# ## Basic Examples

# %%
from sympy import *
t=symbols("t")
fourier_series(t/2,(t,-pi,pi)).truncate(3).rewrite(exp)
# Out:
# -I*(exp(I*t) - exp(-I*t))/2 + I*(exp(2*I*t) - exp(-2*I*t))/4 - I*(exp(3*I*t) - exp(-3*I*t))/6

# %%
from sympy.abc import *
from sympy import *
plot(fourier_series(t/2,(t,-pi,pi)).truncate(3).rewrite(exp),(t,-3*pi,3*pi))

# %%
from sympy.abc import *
from sympy import *
fourier_series(x**2*y,(x,-pi,pi),(y,-pi,pi)).truncate(1).subs(x,1).subs(y,1).evalf()
# I don't know multi-dimension of sympy
# Out:
# 3.28986813369645

# %%
from sympy.abc import *
from sympy import *
from sympy.plotting import *
plot3d(fourier_series(x**2*y,(x,-pi,pi),(y,-pi,pi)).truncate(2),(x,-pi,pi),(y,-pi,pi))
# I don't know multi-dimension of sympy

# %% [markdown]
# ## Scope

# %%
from sympy.abc import *
from sympy import *
fourier_series(E**(-t),(t,-pi,pi)).truncate(4).simplify()
# Out:
# (5*(1 - exp(2*pi))*sin(t) - 4*(1 - exp(2*pi))*sin(2*t) + 3*(1 - exp(2*pi))*sin(3*t) + 5*(1 - exp(2*pi))*cos(t) - 2*(1 - exp(2*pi))*cos(2*t) + (1 - exp(2*pi))*cos(3*t) - 5 + 5*exp(2*pi))*exp(-pi)/(10*pi)

# %%
from sympy.abc import *
from sympy import *
fourier_series(E**(-t**2),(t,-pi,pi)).truncate(3).simplify()
# Out:
# (cos(t)*Integral(exp(-t**2)*cos(t), (t, -pi, pi)) + cos(2*t)*Integral(exp(-t**2)*cos(2*t), (t, -pi, pi)) + sqrt(pi)*erf(pi)/2)/pi

# %%
from sympy.abc import *
from sympy import *
fourier_series(Abs(t),(t,-pi,pi)).truncate(2).rewrite(exp).simplify()
# Out:
# -2*exp(I*t)/pi + pi/2 - 2*exp(-I*t)/pi

# %%
from sympy.abc import *
from sympy import *
plot(Abs(t),fourier_series(Abs(t),(t,-pi,pi)).truncate(2),(t,-pi,pi))

# %%
from sympy.abc import *
from sympy import *
fourier_series(E**(t*I),(t,-pi,pi)).truncate(3)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-907d75d898d2> in <module>
#       1 from sympy.abc import *
#       2 from sympy import *
# ----> 3 fourier_series(E**(t*I),(t,-pi,pi)).truncate(3)
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\series\fourier.py in fourier_series(f, limits, finite)
#     660     else:
#     661         a0, an = fourier_cos_seq(f, limits, n)
# --> 662         bn = fourier_sin_seq(f, limits, n)
#     663
#     664     return FourierSeries(f, limits, (a0, an, bn))
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\series\fourier.py in fourier_sin_seq(func, limits, n)
#      35     sin_term = sin(2*n*pi*x / L)
#      36     return SeqFormula(2 * sin_term * integrate(func * sin_term, limits)
# ---> 37                       / L, (n, 1, oo))
#      38
#      39
#
# ...

# %% [markdown]
# ### Options

# %%
from sympy.abc import *
from sympy import *
fourier_series(E**(-Abs(t)) ,(t,-Rational(1,2),Rational(1,2))).truncate(3).rewrite(exp).expand()
# Out:
# -2*exp(4*I*pi*t)/(exp(1/2) + 16*pi**2*exp(1/2)) + 2*exp(4*I*pi*t)/(1 + 16*pi**2) + 2*exp(2*I*pi*t)/(exp(1/2) + 4*pi**2*exp(1/2)) + 2*exp(2*I*pi*t)/(1 + 4*pi**2) - 2*exp(-1/2) + 2 + 2/(exp(4*I*pi*t) + 16*pi**2*exp(4*I*pi*t)) + 2/(exp(2*I*pi*t) + 4*pi**2*exp(2*I*pi*t)) - 2/(exp(1/2)*exp(4*I*pi*t) + 16*pi**2*exp(1/2)*exp(4*I*pi*t)) + 2/(exp(1/2)*exp(2*I*pi*t) + 4*pi**2*exp(1/2)*exp(2*I*pi*t))
