# %% [markdown]
# # Examples

# %% [markdown]
# ## Basic Examples

# %%
from sympy import sin, pi
sin(pi/3)
# Out:
# sqrt(3)/2

# %%
from sympy import pi, sin, rad
sin(rad(60))
# Out:
# sqrt(3)/2

# %%
from sympy import plot, symbols, sin, pi
from sympy.abc import x
plot(sin(x), (x, 0, 2*pi))

# %%
# complexplot3D
from sympy import *
from sympy.plotting import *
from sympy.abc import x, y
plot3d(
    Abs(sin(x+I*y)),
    (x, -2*pi, 2*pi), (y, -2, 2)
)

# %%
from sympy import series, sin
from sympy.abc import x
sin(x).series(x0=0, n=11)  # 此处 Mathematica 是 Series[Sin[x], {x, 0, 10}]
# Out:
# x - x**3/6 + x**5/120 - x**7/5040 + x**9/362880 + O(x**11)

# %% [markdown]
# ## Scope

# %% [markdown]
# ### Numerical Evaluation

# %%
from sympy import sin
sin(1.2)
# Out:
# 0.932039085967226

# %%
from sympy import sin, Rational
sin(Rational(12, 10)).evalf(n=50)  # 和 Mathematica 一致
# Out:
# 0.93203908596722634967013443549482599541507058820873

# %%
from sympy import sin
sin(1.20000000000000000000000)
# Out:
# 0.932039085967226

# %%
from sympy import sin, I
sin(2.5 + I)
# Out:
# 0.923490776043173 - 0.941504933270867*I

# %% [markdown]
# #### 没有测时间函数

# %%
from sympy import *
sin(AccumBounds(-pi, pi))
# Out:
# AccumBounds(-1, 1)

# %%
from sympy import *
Array(map(sin, [1.2, 1.5, 1.8]))
# Out:
# [0.932039085967226, 0.997494986604054, 0.973847630878195]

# %%
from sympy import *
Matrix([[pi, pi/2], [pi/3, pi/4]]).applyfunc(sin)
# Out:
# Matrix([
# [        0,         1],
# [sqrt(3)/2, sqrt(2)/2]])

# %% [markdown]
# ### Specific Values

# %%
from sympy import *
Array(map(sin, [pi/6*n for n in range(7)]))
# Out:
# [0, 1/2, sqrt(3)/2, 1, sqrt(3)/2, 1/2, 0]

# %%
from sympy import *
sin(oo)
# Out:
# AccumBounds(-1, 1)

# %%
from sympy import *
sin(zoo)
# 这缩写简直了
# Out:
# nan

# %%
from sympy import *
sin(pi/5)
# Out:
# sqrt(5/8 - sqrt(5)/8)

# %%
from sympy import *
sin(pi/24)
# Out:
# -sqrt(3)*sqrt(1/2 - sqrt(2)/4)/2 + sqrt(sqrt(2)/4 + 1/2)/2

# %%
from sympy import *
from sympy.assumptions import *
m = symbols("m", integer=True)
sin(pi*m).simplify()
# Out:
# 0

# %%
from sympy import *
from sympy.assumptions import *
m = symbols("m", integer=True)
sin(pi*(Rational(1, 2) + m)).simplify()
# Out:
# (-1)**m

# %%
from sympy import *
x = symbols("x")
solveset(Eq(diff(sin(x), x), 0), x, domain=Interval.open(0, pi))
# Out:
# FiniteSet(pi/2)

# %%
from sympy import *
from sympy.plotting import *
plot(sin(x), (x, 0, 2*pi))
# 不会加点

# %% [markdown]
# ### Visualization

# %%
from sympy import *
from sympy.plotting import *
plot(sin(x), (x, 0, 4*pi))

# %% [markdown]
# #### sympy 没有等高线绘图函数，等大神补充

# %% [markdown]
# #### sympy 没有极坐标绘图函数，等大神补充

# %% [markdown]
# ## Function Properties

# %%
from sympy import *
from sympy.abc import *
# 好像没定义域函数
solveset(sin(x) < 2, x, domain=Reals)
# Out:
# Reals

# %%
from sympy import *
sin(AccumBounds(-oo, oo))
# Out:
# AccumBounds(-1, 1)

# %%
from sympy import *
periodicity(sin(x), x)
# Out:
# 2*pi

# %%
from sympy import *
sin(-x)
# Out:
# -sin(x)

# %%
from sympy import *
Eq(sin(conjugate(z)), conjugate(sin(z)))
# Out:
# True

# %% [markdown]
# ### Differentiation

# %%
from sympy import *
diff(sin(x), x)
# Out:
# cos(x)

# %%
from sympy import *
from sympy.abc import *
Array(diff(sin(x), x, i) for i in range(1, 5))
# Out:
# [cos(x), -sin(x), -cos(x), sin(x)]

# %%
from sympy.abc import *
from sympy import *
from sympy.plotting import *
plot(*Array(diff(sin(x), x, i) for i in range(1, 5)), (x, -2*pi, 2*pi))

# %%
from sympy import *
from sympy.abc import *
n = symbols("n", integer=True, positive=True)
diff(sin(x), x, n)
# Out:
# 0

# %% [markdown]
# ### Integration

# %%
from sympy import *
integrate(sin(x), x)
# Out:
# -cos(x)

# %%
from sympy import *
integrate(sin(x), (x, 0, 2*pi))
# Out:
# 0

# %%
from sympy import *
integrate(sin(x)*cos(x), x)
# Out:
# sin(x)**2/2

# %%
from sympy import *
from sympy.abc import *
integrate(sin(z)**a, z)
# MMA 算出来了
# Out:
# Integral(sin(z)**a, z)

# %% [markdown]
# ### Series Expansions

# %%
from sympy import *
sin(x).series(n=7)
# Out:
# x - x**3/6 + x**5/120 + O(x**7)

# %%
from sympy.abc import *
from sympy import *
plt = plot(*Array(sin(x).series(n=m).removeO()
                  for m in [3, 5, 7]), sin(x), (x, -2*pi, 2*pi), ylim=(-1.5, 1.5))

# %%
# 不会级数系数列表

# %%
from sympy import *
from sympy.abc import z
fourier_series(sin(z), z, 1)
# 和 MMA 不一样
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-8491f8cacd39> in <module>
#       1 from sympy import *
#       2 from sympy.abc import z
# ----> 3 fourier_series(sin(z),z,1)
#       4 # 不清楚
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\series\fourier.py in fourier_series(f, limits, finite)
#     637     f = sympify(f)
#     638
# --> 639     limits = _process_limits(f, limits)
#     640     x = limits[0]
#     641
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\series\fourier.py in _process_limits(func, limits)
#      83
#      84     if not isinstance(x, Symbol) or start is None or stop is None:
# ---> 85         raise ValueError('Invalid limits given: %s' % str(limits))
#      86
#      87     unbounded = [S.NegativeInfinity, S.Infinity]
#
# ValueError: Invalid limits given: z

# %%
from sympy import *
sin(x).series(n=7).subs(x, sin(x).series(n=7)).expand()
# Out:
# x - x**3/3 + x**5/10 + O(x**7)

# %% [markdown]
# ### Integral Transforms

# %%
from sympy import *
fourier_transform(sin(t), t, k)
# ？？？
# Out:
# 0

# %%
from sympy import *
laplace_transform(sin(t), t, s)[0]
# Out:
# 1/(s**2 + 1)

# %%
from sympy import *
mellin_transform(sin(x), x, s)[0]
# Out:
# 2**s*sqrt(pi)*gamma(s/2 + 1/2)/(2*gamma(1 - s/2))

# %% [markdown]
# ### Function Identities and Simplifications

# %%
from sympy import *
expand_trig(sin(2*x))
# 2sin(x)cos(x)
# Out:
# 2*sin(x)*cos(x)

# %%
from sympy import *
expand_trig(sin(x+y))
# Out:
# sin(x)*cos(y) + sin(y)*cos(x)

# %%
from sympy import *
expand_trig(sin(4*x))
# Out:
# -8*sin(x)**3*cos(x) + 4*sin(x)*cos(x)

# %%
from sympy import *
expand_trig(sin(4*x)).simplify()
# 好像没有 TrigReduce
# Out:
# sin(4*x)

# %%
from sympy import *
# 好像没有 TrigFactor
# Out:
# sin(x) + cos(y)

# %%
from sympy import *
x, y = symbols('x,y', real=True)
expand_complex(sin(x+I*y))
# Out:
# sin(x)*cosh(y) + I*cos(x)*sinh(y)

# %%
from sympy import *
from sympy.abc import *
sin(z).rewrite(exp).expand()
# Out:
# -I*exp(I*z)/2 + I*exp(-I*z)/2

# %% [markdown]
# ### Function Representations

# %%
from sympy import *
cos(pi/2-x)
# Out:
# sin(x)

# %%
from sympy import *
sqrt(pi * x/2)*besselj(Rational(1, 2), x).simplify()
# Out:
# sin(x)

# %%
from sympy import *
-I*sqrt(pi*I * x/2)*besseli(Rational(1, 2), I*x).simplify()
# 应该化成 sin(x)
# Out:
# -I*exp_polar(-I*pi/4)*exp(-I*pi/4)*sin(I*x*exp_polar(I*pi/2))

# %%
from sympy import *
# 没有球面谐函数？

# %%
from sympy import *
sin(x)
# 没有约化函数
# Out:
# sin(x)

# %% [markdown]
# #### 没有 DifferentialRootReduce 微分根约化

# %% [markdown]
# ## Applications

# %%
from sympy import *
from sympy.plotting import *
plot_parametric(cos(x), sin(x), (x, 0, 2*pi))

# %%
from sympy import *
from sympy.plotting import *
t = symbols("t")
plot_parametric(cos(t), sin(2*t), (t, 0, 2*pi))

# %%
from sympy import *
from sympy.plotting import *
t = symbols("t")
plot_parametric(
    *Array(exp(t/10) * i for i in [sin(t), cos(t)]), (t, 0, 10 * pi))

# %% [markdown]
# #### 没有动画功能

# %% [markdown]
# #### 没有声音功能

# %%
from sympy import *
t, ω = symbols('t ω')
x = symbols('x', cls=Function)
dsolve(
    Eq(
        Derivative(x(t), t, t)+ω**2*x(t),
        0
    )
).rewrite(sin)
# Out:
# Eq(x(t), C1*(-I*sin(t*ω) + cos(t*ω)) + C2*(I*sin(t*ω) + cos(t*ω)))

# %% [markdown]
# #### 没有旋转矩阵功能

# %%
from sympy import *
from sympy.plotting import *
Φ, θ = symbols("Φ θ")
plot3d_parametric_surface(cos(Φ)*sin(θ), sin(θ)*sin(Φ),
                          cos(θ),   (Φ, -pi, pi), (θ, -pi, pi))

# %%
from sympy import *
from sympy.plotting import *
Φ, θ = symbols("Φ θ")
plot3d_parametric_surface(
    cos(Φ)+1/2*cos(θ)*cos(Φ),
    sin(Φ)+1/2*cos(θ)*sin(Φ),
    sin(θ)/2,
    (Φ, -pi, pi), (θ, 0, 2*pi)
)

# %%
from sympy import *
from sympy.plotting import *
from sympy.abc import x, y
plot3d(
    sin(x)*sin(y),
    (x, 0, 10*pi), (y, 0, 10*pi)
)

# %% [markdown]
# #### 没有 ContourPlot3D 函数

# %%
from sympy import *
from sympy.printing import *
x = symbols("x")
j = symbols("j")
plot(
    summation(
        sin(j**2*x)/j**2,
        (j, 1, 12)
    ),
    (x, 0, 2*pi)
)

# %% [markdown]
# ## Properties & Relations

# %%
from sympy import *
sin(x+2*pi)
# Out:
# sin(x)

# %%
from sympy import *
sin(-x)
# Out:
# -sin(x)

# %%
from sympy import *
sin(I*x)
# Out:
# I*sinh(x)

# %%
from sympy import *
1/sin(x).rewrite(csc)
# Out:
# csc(x)

# %%
from sympy import *
(sin(3*z))**2 + (2*cos(z)*cos(2*z) - cos(z))**2
# 这个式子 plot 出来=0 ， mma 化简=1，存疑

# %%
from sympy import *
(sin(x)-sin(y)-2*cos((x+y)/2)*sin((x-y)/2)).simplify()
# Out:
# 0

# %%
from sympy import *
Array([sin(asin(z)), sin(2*asin(z)), sin(3*asin(z))])
# FunctionExpand 好像没
# Out:
# [z, sin(2*asin(z)), sin(3*asin(z))]

# %%
from sympy import *
solveset(Eq(sin(z)**2+3*sin(z+pi/6), 4))
# sympy 估计求不出
# Out:
# ConditionSet(z, Eq(sin(z)**2 + 3*sin(z + pi/6) - 4, 0), Reals)

# %%
from sympy import *

# %% [markdown]
# #### 不知道 sympy 有没有求数值解工具

# %%
from sympy import *
α, x, β = symbols("α x β")
solveset(Eq(sin(α*x+β), 0), x)
# sympy 求不出
# Out:
# ConditionSet(x, Eq(-I*(-exp(I*(-x*α - β)) + exp(I*(x*α + β)))/2, 0), Reals)

# %%
from sympy import *
x, y = symbols("x y")
fourier_transform(sin(x), x, y)
# 这个和 MMA 不同，可能是语法原因
# Out:
# 0

# %%
from sympy import *
laplace_transform(sin(t), t, s)[0]
# Out:
# 1/(s**2 + 1)

# %%
from sympy import *
from sympy.abc import z
besselj(Rational(1, 2), z).simplify()
# Out:
# sqrt(2)*sin(z)/(sqrt(pi)*sqrt(z))

# %%
from sympy import *
from sympy.abc import z
mathieus(1, 0, z).simplify()
# Out:
# sin(z)

# %%
from sympy import *
from sympy.abc import z
# 好像没 JacobiSN

# %%
from sympy import *
from sympy.abc import z
hyper([], [Rational(3, 2)], -z).simplify()
# Out:
# sin(2*sqrt(z))/(2*sqrt(z))

# %%
from sympy import *
from sympy.abc import z
meijerg([[], []], [[Rational(1, 2)], [0]], z).simplify()
# sin(2 sqrt(z))/(  sqrt(pi))
# sympy 没求出来
# Out:
# meijerg(((), ()), ((1/2,), (0,)), z)

# %%
from sympy import *
sin(2+E)
# 不会数值量判定
# Out:
# sin(2 + E)

# %% [markdown]
# #### 无 DifferentialRootReduce

# %% [markdown]
# #### 无 GeneratingFunction

# %% [markdown]
# #### 无 ExponentialGeneratingFunction

# %% [markdown]
# ## Possible Issues

# %%
from sympy import *
sin(pi/8).radsimp()
# Out:
# sqrt(2 - sqrt(2))/2

# %%
from sympy import *
sin(pi/12).radsimp()
# Out:
# (-sqrt(2) + sqrt(6))/4

# %%
from sympy import *
sin(pi/15).radsimp()
# Out:
# sqrt(2)*(2*sqrt(6)*(1 - sqrt(5)) + 4*sqrt(sqrt(5) + 5))/32

# %%
from sympy import *
integrate(
    1/(2+sin(x)), x
)
# Out:
# 2*sqrt(3)*(atan(2*sqrt(3)*tan(x/2)/3 + sqrt(3)/3) + pi*floor((x/2 - pi/2)/pi))/3

# %%
from sympy import *
from sympy.plotting import *
x = symbols("x")
plot(
    integrate(
        1/(2+sin(x)), x
    ), (x, -60, 60)
)
# 和 MMA 不一致,已提交 issue

# %% [markdown]
# ## Neat Example

# %%
from sympy import *
from sympy.plotting import *
plot(sin(x)+sin(sqrt(2)*x), (x, 0, 40*pi))

# %%
from sympy import *
sin(pi/2**12).rewrite(sqrt).simplify()
# Out:
# sqrt(2 - sqrt(sqrt(sqrt(sqrt(sqrt(sqrt(sqrt(sqrt(sqrt(sqrt(2) + 2) + 2) + 2) + 2) + 2) + 2) + 2) + 2) + 2))/2

# %%
from sympy import *
n = symbols("n", integer=True)
integrate(sin(x**n), x).simplify()
# 额外加了条件
# Out:
# x**(n + 1)*gamma(1/2 + 1/(2*n))*hyper((1/2 + 1/(2*n),), (3/2, 3/2 + 1/(2*n)), -x**(2*n)/4)/(2*n*gamma(3/2 + 1/(2*n)))
