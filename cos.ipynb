# %% [markdown]
# # Examples

# %% [markdown]
# ## Basic Examples

# %%
from sympy import cos,pi
cos(pi/6)
# Out:
# sqrt(3)/2

# %%
from sympy import pi,cos,rad
cos(rad(30))
# Out:
# sqrt(3)/2

# %%
from sympy import plot,symbols,cos,pi
from sympy.abc import x
plot(cos(x),(x,0,2*pi))

# %%
#### complexplot3D
from sympy import *
from sympy.functions import *
from sympy.plotting import *
from sympy.abc import x,y
plot3d(
    Abs(cos(x+I*y)),
    (x, -2*pi, 2*pi), (y, -2, 2)
    )

# %%
from sympy import series,cos
from sympy.abc import x
cos(x).series(x0=0,n=11) # 此处 Mathematica 是 Series[cos[x], {x, 0, 10}]
# Out:
# 1 - x**2/2 + x**4/24 - x**6/720 + x**8/40320 - x**10/3628800 + O(x**11)

# %% [markdown]
# ## Scope

# %% [markdown]
# ### Numerical Evaluation

# %%
from sympy import cos
cos(1.2)
# Out:
# 0.362357754476674

# %%
from sympy import cos, Rational
cos(Rational(12,10)).evalf(n=50) # 和 Mathematica 一致
# Out:
# 0.36235775447667357763837335562307602033994778557665

# %%
from sympy import cos
cos(1.20000000000000000000000)
# Out:
# 0.362357754476674

# %%
from sympy import cos,I
cos(2.5 + I)
# Out:
# -1.23622919885634 - 0.703325178113535*I

# %% [markdown]
# #### 没有测时间函数

# %%
from sympy import *
cos(AccumBounds(-pi,pi))
# Out:
# AccumBounds(-1, 1)

# %%
from sympy import *
Array([1.2,1.5,1.8]).applyfunc(cos)
# Out:
# [0.362357754476674, 0.0707372016677029, -0.227202094693087]

# %%
from sympy.abc import *
from sympy import *
Matrix([[pi,u],[v,pi/2]]).applyfunc(cos)
# Out:
# Matrix([
# [    -1, cos(u)],
# [cos(v),      0]])

# %% [markdown]
# ### Specific Values

# %%
from sympy import *
Array([pi/6*n for n in range(7)]).applyfunc(cos)
# Out:
# [1, sqrt(3)/2, 1/2, 0, -1/2, -sqrt(3)/2, -1]

# %%
from sympy import *
cos(oo)
# Out:
# AccumBounds(-1, 1)

# %%
from sympy import *
cos(zoo)
# 这缩写简直了
# Out:
# nan

# %%
from sympy import *
from sympy.assumptions import *
m=symbols("m",integer=True)
cos(pi*(Rational(1,2)+ m)).simplify()
# Out:
# 0

# %%
from sympy import *
from sympy.assumptions import *
m=symbols("m",integer=True)
cos(pi*m).simplify()
# Out:
# (-1)**m

# %%
from sympy import *
x=symbols("x")
solveset(Eq(diff(cos(x),x),0),x,domain=Interval.open(0,2*pi))
# Out:
# FiniteSet(pi)

# %%
from sympy import *
from sympy.plotting import *
plot(cos(x),(x,0,2*pi))
# 不会加点

# %%
from sympy import *
cos(pi/5)
# Out:
# 1/4 + sqrt(5)/4

# %%
from sympy import *
cos(pi/24)
# Out:
# sqrt(1/2 - sqrt(2)/4)/2 + sqrt(3)*sqrt(sqrt(2)/4 + 1/2)/2

# %% [markdown]
# ### Visualization

# %%
from sympy import *
from sympy.plotting import *
plot(cos(x),(x,-2*pi,2*pi))

# %% [markdown]
# #### sympy 没有等高线绘图函数，等大神补充

# %% [markdown]
# #### sympy 没有极坐标绘图函数，等大神补充

# %% [markdown]
# ## Function Properties

# %%
from sympy import *
from sympy.abc import *
##### 好像没定义域函数
solveset(cos(x)<2,x,domain=Reals)
# Out:
# Reals

# %%
from sympy import *
cos(AccumBounds(-oo,oo))
# Out:
# AccumBounds(-1, 1)

# %%
from sympy import *
periodicity(cos(x),x)
# Out:
# 2*pi

# %%
from sympy import *
cos(-x)
# Out:
# cos(x)

# %%
from sympy import *
Eq(cos(conjugate(z)),conjugate(cos(z)))
# Out:
# True

# %% [markdown]
# ### Differentiation

# %%
from sympy import *
diff(cos(x),x)
# Out:
# -sin(x)

# %%
from sympy import *
from sympy.abc import *
Array(range(1,5)).applyfunc(lambda i:diff(cos(x),x,i))
# Out:
# [-sin(x), -cos(x), sin(x), cos(x)]

# %%
from sympy.abc import *
from sympy import *
from sympy.plotting import *
Array(range(1,5)).applyfunc(lambda i:diff(cos(x),x,i))
plot(*Array(range(1,5)).applyfunc(lambda i:diff(cos(x),x,i)),(x,-pi,pi))

# %%
from sympy import *
from sympy.abc import *
n=symbols("n",integer=True,positive=True)
diff(cos(x),x,n)
# Out:
# 0

# %% [markdown]
# ### Integration

# %%
from sympy import *
integrate(cos(x),x)
# Out:
# sin(x)

# %%
from sympy import *
integrate(cos(x),(x,0,2*pi))
# Out:
# 0

# %%
from sympy import *
integrate(sin(x)*cos(x),x)
# Out:
# sin(x)**2/2

# %%
from sympy import *
from sympy.abc import *
integrate(cos(z)**a,z)
# MMA 算出来了
# Out:
# Integral(cos(z)**a, z)

# %% [markdown]
# ### Series Expansions

# %%
from sympy import *
cos(x).series(n=9)
# Out:
# 1 - x**2/2 + x**4/24 - x**6/720 + x**8/40320 + O(x**9)

# %%
from sympy.abc import *
from sympy import *
plot(*Array([4,6,8]).applyfunc(lambda m:cos(x).series(n=m).removeO()),cos(x),(x,-2*pi,2*pi),ylim=(-1.5,1.5))

# %% [markdown]
# #### 不会级数系数列表

# %%
from sympy import *
from sympy.abc import z
fourier_series(cos(z),z,1)
# 和 MMA 不一样
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-170-12b2d77d8025> in <module>
#       1 from sympy import *
#       2 from sympy.abc import z
# ----> 3 fourier_series(cos(z),z,1)
#       4 # 和 MMA 不一样
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\series\fourier.py in fourier_series(f, limits, finite)
#     637     f = sympify(f)
#     638
# --> 639     limits = _process_limits(f, limits)
#     640     x = limits[0]
#     641
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\series\fourier.py in _process_limits(func, limits)
#      83
#      84     if not isinstance(x, Symbol) or start is None or stop is None:
# ---> 85         raise ValueError('Invalid limits given: %s' % str(limits))
#      86
#      87     unbounded = [S.NegativeInfinity, S.Infinity]
#
# ValueError: Invalid limits given: z

# %%
from sympy import *
cos(x).series(n=8).subs(x,cos(x).series(n=8)).expand()
# issue 已提
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\Program Files\Python3.7\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      93                 try:
# ---> 94                     retval = cfunc(*args, **kwargs)
#      95                 except TypeError:
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\core\basic.py in _subs(self, old, new, **hints)
#    1113
# -> 1114         rv = self._eval_subs(old, new)
#    1115         if rv is None:
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\series\order.py in _eval_subs(self, old, new)
#     445                             sol = set(e1) - set(e2)
# --> 446                         res = [dict(zip((d, ), sol))]
#     447                         point = d.subs(res[0]).limit(old, self.point[i])
#
# TypeError: zip argument #2 must support iteration
#
# ...

# %% [markdown]
# ### Integral Transforms

# %%
from sympy import *
fourier_transform(cos(t),t,k)
# ？？？
# Out:
# 0

# %%
from sympy import *
laplace_transform(cos(t),t,s)[0]
# Out:
# s/(s**2 + 1)

# %%
from sympy import *
mellin_transform(cos(x),x,s)[0]
# Out:
# 2**s*sqrt(pi)*gamma(s/2)/(2*gamma(1/2 - s/2))

# %% [markdown]
# ### Function Identities and Simplifications

# %%
from sympy import *
expand_trig(cos(2*x))
# 2cos(x)cos(x)
# Out:
# 2*cos(x)**2 - 1

# %%
from sympy import *
expand_trig(cos(x+y))
# Out:
# -sin(x)*sin(y) + cos(x)*cos(y)

# %%
from sympy import *
expand_trig(cos(4*x))
# Out:
# 8*cos(x)**4 - 8*cos(x)**2 + 1

# %%
from sympy import *
expand_trig(cos(4*x)).simplify()
# 好像没有 TrigReduce
# Out:
# 8*cos(x)**4 - 8*cos(x)**2 + 1

# %%
from sympy import *
# 好像没有 TrigFactor

# %%
from sympy import *
x, y = symbols('x,y', real=True)
expand_complex(cos(x+I*y))
# Out:
# -I*sin(x)*sinh(y) + cos(x)*cosh(y)

# %%
from sympy import *
from sympy.abc import *
cos(z).rewrite(exp).expand()
# Out:
# exp(I*z)/2 + exp(-I*z)/2

# %% [markdown]
# ### Function Representations

# %%
from sympy import *
sin(pi/2-x)
# Out:
# cos(x)

# %%
from sympy import *
sqrt(pi *x/2)*besselj(-Rational(1,2),x).simplify()
# Out:
# cos(x)

# %%
from sympy import *
-I*sqrt(pi*I *x/2)*besseli(-Rational(1,2),I*x).simplify()
# 应该化成 cos(x)
# Out:
# -I*exp_polar(-I*pi/4)*exp(I*pi/4)*cos(I*x*exp_polar(I*pi/2))

# %%
from sympy import *
# 没有球面谐函数？

# %%
from sympy import *
cos(x)
# 没有约化函数
# Out:
# cos(x)

# %% [markdown]
# #### 没有 DifferentialRootReduce 微分根约化

# %% [markdown]
# ## Applications

# %%
from sympy import *
from sympy.plotting import *
plot_parametric(cos(t),sin(t),(t,0,2*pi))

# %%
from sympy import *
from sympy.plotting import *
t=symbols("t")
plot_parametric(cos(2*t),cos(5*t),(t,0,2*pi))

# %%
from sympy import *
from sympy.plotting import *
t=symbols("t")
plot_parametric(exp(t/10)*cos(t),exp(t/10)*sin(t), (t, 0, 10* pi))

# %% [markdown]
# #### 没有动画功能

# %%
from sympy import *
t,ω=symbols('t ω')
x=symbols('x',cls=Function)
dsolve(
    Eq(
        Derivative(x(t),t,t)+ω**2*x(t),
        0
        )
    ).rewrite(cos)
# Out:
# Eq(x(t), C1*(-I*sin(t*ω) + cos(t*ω)) + C2*(I*sin(t*ω) + cos(t*ω)))

# %% [markdown]
# #### 没有旋转矩阵功能

# %%
from sympy import *
from sympy.plotting import *
Φ,θ=symbols("Φ θ")
plot3d_parametric_surface(
    cos(Φ)*sin(θ), 
    sin(θ)*sin(Φ),
    cos(θ),
    (Φ, -pi,pi), (θ, -pi, pi)
)

# %%
from sympy import *
from sympy.plotting import *
Φ,θ=symbols("Φ θ")
plot3d_parametric_surface(
    cos(Φ)+1/2*cos(θ)*cos(Φ),
    sin(Φ)+1/2*cos(θ)*sin(Φ),
    sin(θ)/2,
    (Φ, -pi, pi), (θ, 0, 2*pi)
    )

# %%
from sympy import *
from sympy.plotting import *
from sympy.abc import x,y
plot3d(
    cos(x)*cos(y),
    (x, 0, 10*pi), (y, 0, 10*pi)
    )

# %% [markdown]
# #### 没有 ContourPlot3D 函数

# %%
from sympy import *
from sympy.printing import *
x=symbols("x")
j=symbols("j")
plot(
    summation(
        cos(j**2*x)/j**2,
        (j,1,12)
        ),
        (x,0,2*pi)
    )
# 已提 issue

# %% [markdown]
# ## Properties & Relations

# %%
from sympy import *
cos(x+2*pi)
# Out:
# cos(x)

# %%
from sympy import *
cos(-x)
# Out:
# cos(x)

# %%
from sympy import *
cos(I*x)
# Out:
# cosh(x)

# %%
from sympy import *
1/cos(x).rewrite(sec)
# Out:
# sec(x)

# %%
from sympy import *
(cos(3*z))**2 - (  3*cos(z)*sin(z)- cos(z)**3  )**2
# 这个式子 plot 出来=0 ， mma 化简=1，存疑
# Out:
# -(3*sin(z)*cos(z) - cos(z)**3)**2 + cos(3*z)**2

# %%
from sympy import *
((cos(3*z))**2 - (  3*cos(z)*sin(z)- cos(z)**3  )**2).simplify()
# sympy 无法化简
# Out:
# -(3*sin(z) - cos(z)**2)**2*cos(z)**2 + cos(3*z)**2

# %% [markdown]
# #### 这段不打了

# %%
from sympy import *
Array([cos(acos(z)),cos(2*acos(z)),cos(3*acos(z))])
# FunctionExpand 好像没
# Out:
# [z, cos(2*acos(z)), cos(3*acos(z))]

# %% [markdown]
# #### no funcexpand

# %%
from sympy import *
solveset(Eq(cos(z)**2+3*cos(z+pi/6),4))
# sympy 估计求不出
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-268-c5051561aca2> in <module>
#       1 from sympy import *
# ----> 2 solveset(Eq(cos(z)**2+3*cos(z+pi/6),4))
#       3 # sympy 估计求不出
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\solvers\solveset.py in solveset(f, symbol, domain)
#    2009     f = piecewise_fold(f)
#    2010
# -> 2011     return _solveset(f, symbol, domain, _check=True)
#    2012
#    2013
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\solvers\solveset.py in _solveset(f, symbol, domain, _check)
#     924             result += solns
#     925     elif isinstance(f, Eq):
# --> 926         result = solver(Add(f.lhs, - f.rhs, evaluate=False), symbol, domain)
#     927
#     928     elif f.is_Relational:
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\solvers\solveset.py in <lambda>(f, x, domain)
#     891
# ...

# %%
from sympy import *

# %% [markdown]
# #### 不知道 sympy 有没有求数值解工具

# %%
from sympy import *
α,x,β=symbols("α x β")
solveset(Eq(cos(α*x+β),0),x)
# sympy 求不出
# Out:
# ConditionSet(x, Eq((exp(I*(-x*α - β)) + exp(I*(x*α + β)))/2, 0), Reals)

# %%
from sympy import *
integrate(cos(z)**a,z)
# Out:
# Integral(cos(z)**a, z)

# %%
from sympy import *
from sympy.abc import z
besselj(-Rational(1,2),z).simplify()
# Out:
# sqrt(2)*cos(z)/(sqrt(pi)*sqrt(z))

# %%
from sympy import *
from sympy.abc import z
mathieuc(1,0,z).simplify()
# Out:
# cos(z)

# %%
from sympy import *
from sympy.abc import z
# 好像没 JacobiCD

# %%
from sympy import *
from sympy.abc import z
# no Hypergeometric0F1

# %%
from sympy import *
from sympy.abc import z
meijerg([[],[]],[[0],[Rational(1,2)]],z).simplify()
# cos(2 sqrt(z))/(  sqrt(pi))
# sympy 没求出来
# Out:
# meijerg(((), ()), ((0,), (1/2,)), z)

# %%
# no Attributes

# %%
# no NumericQ

# %% [markdown]
# #### 无 GeneratingFunction

# %% [markdown]
# #### 无 ExponentialGeneratingFunction

# %% [markdown]
# ## Possible Issues

# %%
from sympy import *
integrate(
    1/(2+cos(x)),x
    )
# Out:
# 2*sqrt(3)*(atan(sqrt(3)*tan(x/2)/3) + pi*floor((x/2 - pi/2)/pi))/3

# %%
from sympy import *
from sympy.plotting import *
x=symbols("x")
plot(
    integrate(
        1/(2+cos(x)),x
    ),(x,-60,60)
)
# 和 MMA 不一致,不知道哪个是对的

# %% [markdown]
# ## Neat Example

# %%
from sympy import *
from sympy.plotting import *
plot(cos(x)+cos(sqrt(2)*x),(x,0,40*pi))

# %%
from sympy import *
cos(pi/2**12).rewrite(sqrt).simplify()
# Out:
# sqrt(sqrt(sqrt(sqrt(sqrt(sqrt(sqrt(sqrt(sqrt(sqrt(sqrt(2) + 2) + 2) + 2) + 2) + 2) + 2) + 2) + 2) + 2) + 2)/2

# %%
from sympy import *
x=symbols("x")
Array([1,2,3]).applyfunc(lambda n :integrate(cos(x**n),x).simplify())
# Out:
# [sin(x), sqrt(2)*sqrt(pi)*fresnelc(sqrt(2)*x/sqrt(pi))/2, x*hyper((1/6,), (1/2, 7/6), -x**6/4)]

# %%
from sympy import *
from sympy.plotting import *
