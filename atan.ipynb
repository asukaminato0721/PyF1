# %% [markdown]
# # Examples

# %% [markdown]
# ## Basic Examples

# %%
from sympy import atan,pi
atan(1)
# Out:
# sqrt(3)/2

# %%
from sympy import *
deg(atan(1))
# Out:
# 45

# %%
from sympy import *
atan2(1,1)
# Out:
# pi/4

# %%
from sympy import *
atan2(-1,-1)
# Out:
# -3*pi/4

# %%
from sympy import *

# %%
from sympy import *

# %%
from sympy import *

# %%
from sympy import *

# %%
from sympy import plot,symbols,atan,pi
from sympy.abc import x
plot(atan(x),(x,-5,5))

# %%
#### complexplot3D
from sympy import *
from sympy.functions import *
from sympy.plotting import *
from sympy.abc import x,y
plot3d(
    Abs(atan((x+I*y)**2)),
    (x, -1/2, 1/2), (y, -1, 1)
    )

# %%
from sympy import series,atan
from sympy.abc import x
atan(x).series(x0=0,n=16) # 此处 Mathematica 是 Series[atan[x], {x, 0, 10}]
# Out:
# x - x**3/3 + x**5/5 - x**7/7 + x**9/9 - x**11/11 + x**13/13 - x**15/15 + O(x**16)

# %%
from sympy import series,atan
from sympy.abc import x
atan(x).series(x0=oo,n=6) # 此处 Mathematica 是 Series[atan[x], {x, 0, 10}]
# Out:
# -1/(5*x**5) + 1/(3*x**3) - 1/x + pi/2 + O(x**(-6), (x, oo))

# %%
from sympy import *
from sympy.abc import x
atan(x).series(x0=I,n=3) # 无法在 I 处展开
# Out:
# ---------------------------------------------------------------------------
# PoleError                                 Traceback (most recent call last)
# <ipython-input-15-fa0d1531946d> in <module>
#       1 from sympy import *
#       2 from sympy.abc import x
# ----> 3 atan(x).series(x0=I,n=3) # 此处 Mathematica 是 Series[atan[x], {x, 0, 10}]
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\core\expr.py in series(self, x, x0, n, dir, logx)
#    2824                 rep2 = x
#    2825                 rep2b = -x0
# -> 2826             s = self.subs(x, rep).series(x, x0=0, n=n, dir='+', logx=logx)
#    2827             if n is None:  # lseries...
#    2828                 return (si.subs(x, rep2 + rep2b) for si in s)
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\core\expr.py in series(self, x, x0, n, dir, logx)
#    2834             # replace x with an x that has a positive assumption
#    2835             xpos = Dummy('x', positive=True, finite=True)
# ...

# %% [markdown]
# ## Scope

# %% [markdown]
# ### Numerical Evaluation

# %%
from sympy import atan
atan(0.5)
# Out:
# 0.463647609000806

# %%
from sympy import atan
atan2(2,0.5)
# Out:
# 1.32581766366803

# %%
from sympy import atan, Rational
atan(Rational(1,2)).evalf(n=50) # 和 Mathematica 一致
# Out:
# 0.46364760900080611621425623146121440202853705428612

# %%
from sympy import atan
atan(0.50000000000000000000000000000000000000000)
# Out:
# 0.463647609000806

# %%
from sympy import atan,I
atan(2.5 + I)
# Out:
# 1.23342585568312 + 0.123674060459027*I

# %% [markdown]
# #### 没有测时间函数

# %%
from sympy import *
atan(AccumBounds(-1,3)).simplify()
# 没化简
# Out:
# -atan(AccumBounds(-3, 1))

# %%
from sympy import *
Array([0.1,0.2,0.3]).applyfunc(atan)
# Out:
# [0.0996686524911620, 0.197395559849881, 0.291456794477867]

# %%
from sympy import *
Matrix([[1,Rational(1,3)],[x,Rational(1,2)]]).applyfunc(atan)
# Out:
# Matrix([
# [   pi/4, atan(1/3)],
# [atan(x), atan(1/2)]])

# %% [markdown]
# ### Specific Values

# %%
from sympy import *
Array(range(-1,2)).applyfunc(atan)
# Out:
# [-pi/4, 0, pi/4]

# %%
from sympy import *


def atan_mma(x, y):
    return atan2(y, x)


Matrix([
    [[-2, -2], [-2, -1], [-2, 0], [-2, 1], [-2, 2]],
    [[-1, -2], [-1, -1], [-1, 0], [-1, 1], [-1, 2]],
    [[0, -2], [0, -1], [0, 0], [0, 1], [0, 2]],
    [[1, -2], [1, -1], [1, 0], [1, 1], [1, 2]],
    [[2, -2], [2, -1], [2, 0], [2, 1], [2, 2]]]
).applyfunc(lambda x: atan_mma(*x))
# 因为 Mathematica 和 sympy 的 arctan 是反的
# Out:
# Matrix([
# [      -3*pi/4, -pi + atan(1/2),  pi, pi - atan(1/2),       3*pi/4],
# [-pi + atan(2),         -3*pi/4,  pi,         3*pi/4, pi - atan(2)],
# [        -pi/2,           -pi/2, nan,           pi/2,         pi/2],
# [     -atan(2),           -pi/4,   0,           pi/4,      atan(2)],
# [        -pi/4,      -atan(1/2),   0,      atan(1/2),         pi/4]])

# %%
from sympy import *
atan(oo)
# Out:
# pi/2

# %%
from sympy import *
atan(zoo)
# 这缩写简直了
# 和 MMA 不同
# Out:
# AccumBounds(-pi/2, pi/2)

# %%
from sympy import *
atan2(1,oo)
# Out:
# 0

# %%
from sympy import *
atan2(+oo,-1)
# 和 MMA 不一致
# Out:
# nan

# %%
from sympy import *
atan(0)
# Out:
# 0

# %%
from sympy import *
f=symbols("f",cls=Function)
x=symbols("x")
f=atan(x)-pi/3
solveset(Eq(f,0))
# Out:
# FiniteSet(sqrt(3))

# %%
from sympy import *
from sympy.plotting import *
f=symbols("f",cls=Function)
x=symbols("x")
f=atan(x)-pi/3
plot(f,(x,-2,2))
# 不会加点

# %% [markdown]
# ### Visualization

# %%
from sympy import *
from sympy.plotting import *
plot(atan(x),(x,-7,7))

# %%
from sympy import *
from sympy.plotting import *
plot3d(atan2(y,x),(x,-7,7),(y,-7,7))
# Out:
# D:\Program Files\Python3.7\lib\site-packages\sympy\plotting\experimental_lambdify.py:165: UserWarning: The evaluation of the expression is problematic. We are trying a failback method that may still work. Please report this as a bug.
#   warnings.warn('The evaluation of the expression is'

# %% [markdown]
# #### sympy 没有等高线绘图函数，等大神补充

# %% [markdown]
# #### sympy 没有极坐标绘图函数，等大神补充

# %%
from sympy import *
atan(pi/24)
# Out:
# -sqrt(3)*sqrt(1/2 - sqrt(2)/4)/2 + sqrt(sqrt(2)/4 + 1/2)/2

# %%
from sympy import *
atan(pi/5)
# Out:
# sqrt(5/8 - sqrt(5)/8)

# %%
from sympy import *
from sympy.assumptions import *
m=symbols("m",integer=True)
atan(pi*m).simplify()
# Out:
# 0

# %%
from sympy import *
Array(range(-1,2)).applyfunc(atan)
# Out:
# [-pi/4, 0, pi/4]

# %% [markdown]
# ## Function Properties

# %%
from sympy import *
from sympy.abc import *
##### 好像没定义域函数
solveset(atan(x)<pi,x,domain=Reals)
# Out:
# ConditionSet(x, atan(x) < pi, Reals)

# %%
from sympy import *
atan(AccumBounds(-oo,oo))
# 没出结果
# Out:
# atan(AccumBounds(-oo, oo))

# %%
from sympy import *
atan(-x)
# Out:
# -atan(x)

# %%
from sympy import *
Eq(atan(conjugate(z)),conjugate(atan(z)))
# 没出结果
# Out:
# Eq(atan(conjugate(z)), conjugate(atan(z)))

# %% [markdown]
# ### Differentiation

# %%
from sympy import *
diff(atan(x),x)
# Out:
# 1/(x**2 + 1)

# %%
from sympy import *
from sympy.abc import *
Array(range(1,5)).applyfunc(lambda i:diff(atan(x),x,i).radsimp())
# Out:
# [1/(x**2 + 1), -2*x/(x**2 + 1)**2, (6*x**2 - 2)/(x**2 + 1)**3, 24*x*(1 - x**2)/(x**2 + 1)**4]

# %%
from sympy import *
from sympy.abc import *
from sympy.plotting import *
plot(*Array(range(1,5)).applyfunc(lambda i:diff(atan(x),x,i)),(x,-1,1))

# %%
from sympy import *
from sympy.abc import *
n=symbols("n",integer=True,positive=True)
diff(atan(x),x,n)
# Out:
# 0

# %% [markdown]
# ### Integration

# %%
from sympy import *
integrate(atan(x),x)
# Out:
# x*atan(x) - log(x**2 + 1)/2

# %%
from sympy import *
integrate(atan(x),(x,-1,1))
# Out:
# 0

# %%
from sympy import *
integrate(atan(x)*x,x)
# Out:
# x**2*atan(x)/2 - x/2 + atan(x)/2

# %%
from sympy import *
from sympy.abc import *
integrate(atan(z)*z**k,z)
# MMA 算出来了
# Out:
# Integral(z**k*atan(z), z)

# %% [markdown]
# ### Series Expansions

# %%
from sympy import *
atan(x).series(n=8)
# Out:
# x - x**3/3 + x**5/5 - x**7/7 + O(x**8)

# %% [markdown]
# #### 画不来批量的图

# %% [markdown]
# #### 不会级数系数列表

# %%
from sympy import *
from sympy.abc import z
# 无法在 I 2I 展开
# 和 MMA 不一样
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-8491f8cacd39> in <module>
#       1 from sympy import *
#       2 from sympy.abc import z
# ----> 3 fourier_series(sin(z),z,1)
#       4 # 不清楚
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\series\fourier.py in fourier_series(f, limits, finite)
#     637     f = sympify(f)
#     638
# --> 639     limits = _process_limits(f, limits)
#     640     x = limits[0]
#     641
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\series\fourier.py in _process_limits(func, limits)
#      83
#      84     if not isinstance(x, Symbol) or start is None or stop is None:
# ---> 85         raise ValueError('Invalid limits given: %s' % str(limits))
#      86
#      87     unbounded = [S.NegativeInfinity, S.Infinity]
#
# ValueError: Invalid limits given: z

# %%
from sympy import *
tan(x).series(n=10).subs(x,atan(x).series(n=10)).expand()
# Out:
# x + O(x**10)

# %% [markdown]
# ### Integral Transforms

# %%
from sympy import *
laplace_transform(atan(t),t,s)
# 没算出来
# Out:
# LaplaceTransform(atan(t), t, s)

# %%
from sympy import *
inverse_fourier_transform(atan(t),t,k)
# ？？？
# 没出来
# Out:
# InverseFourierTransform(atan(t), t, k)

# %%
from sympy import *
mellin_transform(atan(x),x,s)
# 等很久都没出
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-85-63419b3bb790> in <module>
#       1 from sympy import *
# ----> 2 mellin_transform(atan(x),x,s)
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\integrals\transforms.py in mellin_transform(f, x, s, **hints)
#     362     hankel_transform, inverse_hankel_transform
#     363     """
# --> 364     return MellinTransform(f, x, s).doit(**hints)
#     365
#     366
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\integrals\transforms.py in doit(self, **hints)
#     121             try:
#     122                 return self._compute_transform(self.function,
# --> 123                     self.function_variable, self.transform_variable, **hints)
#     124             except IntegralTransformError:
#     125                 pass
#
# ...

# %% [markdown]
# ### Function Identities and Simplifications

# %%
from sympy import *
expand_trig(tan(atan(x)+atan(y)))
# Out:
# (x + y)/(-x*y + 1)

# %%
from sympy import *
atan(z).rewrite(log)
# Out:
# I*(log(-I*z + 1) - log(I*z + 1))/2

# %%
from sympy import *
atan(z).rewrite(log).rewrite(atan)
# 变不回去
# Out:
# I*(log(-I*z + 1) - log(I*z + 1))/2

# %%
from sympy import *
x, y = symbols('x,y', real=True)
expand_complex(atan(x+I*y))
# sympy failed
# Out:
# re(atan(x + I*y)) + I*im(atan(x + I*y))

# %%
from sympy import *
expand_trig(atan(4*x)).simplify()
# 好像没有 TrigReduce
# Out:
# sin(4*x)

# %%
from sympy import *
# 好像没有 TrigFactor
# Out:
# sin(x) + cos(y)

# %%
from sympy import *
from sympy.abc import *
atan(z).rewrite(exp).expand()
# Out:
# -I*exp(I*z)/2 + I*exp(-I*z)/2

# %% [markdown]
# ### Function Representations

# %%
from sympy import *
acot(1/x).rewrite(atan)
# Out:
# atan(x)

# %%
from sympy import *
# no InverseJacobiCS
# no InverseJacobiCS

# %%
from sympy import *
# no Hypergeometric2F1
# Out:
# -I*exp_polar(-I*pi/4)*exp(-I*pi/4)*sin(I*x*exp_polar(I*pi/2))

# %%
from sympy import *
# 没有球面谐函数？

# %%
from sympy import *
# 没有约化函数

# %% [markdown]
# #### 没有 DifferentialRootReduce 微分根约化

# %% [markdown]
# ## Applications

# %%
from sympy import *
Array([atan2(3,4),atan2(4,3)]).applyfunc(lambda x:deg(x).evalf())
# Out:
# [36.8698976458440, 53.1301023541560]

# %%
from sympy import *
sum(list(Array([atan2(3,4),atan2(4,3)]).applyfunc(lambda x:deg(x).evalf())))
# Out:
# 90.0000000000000

# %%
from sympy import *
integrate(1/(x**2+1),x)
# Out:
# atan(x)

# %%
from sympy import *
expand_trig(tan(atan(x)+atan(y)))
# Out:
# (x + y)/(-x*y + 1)

# %%
from sympy import *
from sympy.plotting import *
plot3d(re(atan(x+I*y)),(y,-2,2),(x,-2.5,2.5))

# %%
from sympy import *

# %% [markdown]
# ## Properties & Relations

# %%
from sympy import *
atan(z).rewrite(log)
# Out:
# I*(log(-I*z + 1) - log(I*z + 1))/2

# %%
from sympy import *
atan(z).rewrite(log).rewrite(atan)
# Out:
# I*(log(-I*z + 1) - log(I*z + 1))/2

# %%
from sympy import *
(16*atan(Rational(1,5))-4*atan(Rational(1,239))).evalf()
# 无法识别 pi
# Out:
# 3.14159265358979

# %%
from sympy import *
# no Hypergeometric2F1
# Out:
# csc(x)

# %%
from sympy import *
solveset(atan(x)>pi/3,domain=Reals)
# Out:
# Interval.open(sqrt(3), oo)

# %% [markdown]
# ## Possible Issues

# %%
from sympy import *
atan(tan(4))
# Out:
# 4 - pi

# %%
from sympy import *
(atan(tan(4))-4)/pi
# Out:
# -1

# %% [markdown]
# ## Neat Example

# %%
from sympy import *
from sympy.plotting import *
atan(x).series(x0=I,n=3)
# 不支持在 I 展开
# Out:
# atan(pi) + (x - pi)/(1 + pi**2) - pi*(x - pi)**2/(1 + 2*pi**2 + pi**4) + O((x - pi)**3, (x, pi))
