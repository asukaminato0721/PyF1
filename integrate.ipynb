# %% [markdown]
# # Examples

# %%
from sympy.abc import *
from sympy import *

# %% [markdown]
# ## Basic Examples

# %%
integrate(x**2 + sin(x), x)
# Out:
# x**3/3 - cos(x)

# %%
integrate(1 / (x**3 + 1), (x, 0, 1))
# Out:
# log(2)/3 + sqrt(3)*pi/9

# %%
plot(1 / (x**3 + 1), (x, 0, 1), axis_center=(0, 0.5))

# %%
integrate(sqrt(x + sqrt(x)), x)
# Out:
# Integral(sqrt(sqrt(x) + x), x)

# %%
integrate(log(x) * exp(-x**2), (x, 0, oo))
# Out:
# -sqrt(pi)*log(2)/2 - EulerGamma*sqrt(pi)/4

# %%
int = integrate(1 / (x**3 + 1), x)
int
# Out:
# log(x + 1)/3 - log(x**2 - x + 1)/6 + sqrt(3)*atan(2*sqrt(3)*x/3 - sqrt(3)/3)/3

# %%
int = integrate(1 / (x**3 + 1), x)
diff(int, x).simplify()
# Out:
# 1/(x**3 + 1)

# %%
integrate(a * x**2 + b * x + c, x)
# Out:
# a*x**3/3 + b*x**2/2 + c*x

# %%
integrate((2 * x + 3) / (x**2 + 5 * x + 6), (x, 0, 2))
# Out:
# -3*log(3) - log(4) + log(2) + 3*log(5)

# %%
integrate(besselj(2, x) / (1 + x**2), (x, 0, oo))
# Out:
# hyper((1,), (1/2, 5/2), 1/4)/3 - pi*besseli(2, 1)/2

# %%
integrate(sin(x) / x, (x, -oo, oo))
# Out:
# pi

# %%
integrate(cos(x), (x, 0, pi))
# Out:
# 0

# %%
integrate((a * x) / (x**3 + 2), (x, 1, oo))
# Out:
# a*(-2**(2/3)*exp(I*pi/3)*log(-2**(1/3)*exp_polar(5*I*pi/3) + 1)/6 + 2**(2/3)*log(1 - 2**(1/3)*exp_polar(I*pi))/6 - 2**(2/3)*exp(-I*pi/3)*log(1 - 2**(1/3)*exp_polar(I*pi/3))/6)*gamma(1/3)/(3*gamma(4/3))

# %%
integrate(exp(-c * x**2), (x, -oo, oo))
# Out:
# Piecewise((sqrt(pi)/sqrt(c), Abs(arg(c)) <= pi/2), (Integral(exp(-c*x**2), (x, -oo, oo)), True))

# %%
integrate(besselj(3, y) / (x + 1), (x, 0, 5), (y, 0, 5))
# Out:
# (-besselj(2, 5) - 2*besselj(1, 5)/5)*log(6) + log(6)

# %%
integrate(exp(-x + y), (x, 0, oo), (y, 0, 1))
# Out:
# -1 + E

# %%
integrate(sin(x * y), (x, 0, 1), (y, 0, x))
# Out:
# log(x) - Ci(x) + EulerGamma

# %%
from sympy.plotting import *
plot3d(sin(x * y), (x, -1, 1), (y, -1, 1))

# %%
f = Function("f")
integrate(f(x).diff(x), x)
# Out:
# f(x)

# %%
integrate(((1 - f(x)) * f(x).diff(x)) / E**f(x), x)
# Out:
# f(x)*exp(-f(x))

# %%
Array(integrate(f, (x, 0, 5)) for f in (x, 1 / sqrt(x), sin(x)))
# Out:
# [25/2, 2*sqrt(5), 1 - cos(5)]

# %%
Matrix(((x, sqrt(x), x**Rational(1, 3)), (sqrt(x), x**Rational(1, 3),
                                          x**Rational(1, 4)),
        (x**Rational(1, 3), x**Rational(1, 4),
         x**Rational(1, 5)))).applyfunc(lambda j: integrate(j, (x, 0, 5)))
# Out:
# Matrix([
# [         25/2,  10*sqrt(5)/3, 15*5**(1/3)/4],
# [ 10*sqrt(5)/3, 15*5**(1/3)/4,    4*5**(1/4)],
# [15*5**(1/3)/4,    4*5**(1/4), 25*5**(1/5)/6]])

# %%
integrate(E**(-x**x), (x, 0, 1))
# Out:
# Integral(exp(-x**x), (x, 0, 1))

# %%
integrate(E**(-x**x), (x, 0, 1))
# Out:
# Integral(exp(-x**x), (x, 0, 1))

# %%
integrate(x**n, x)
# Out:
# Piecewise((x**(n + 1)/(n + 1), Ne(n, -1)), (log(x), True))

# %%
integrate(1 / x, x)
# Out:
# log(x)

# %%
integrate(sec(x)**2, x)
# Out:
# sin(x)/cos(x)

# %%
integrate(sec(x), x)
# Out:
# -log(sin(x) - 1)/2 + log(sin(x) + 1)/2

# %%
integrate(1 / (x**4 - 1), x)
# Out:
# log(x - 1)/4 - log(x + 1)/4 - atan(x)/2

# %%
integrate((x + 1) / (a**2 * x**2 + c**2), x).simplify()
# Out:
# (-(I*a - c)*log((a*x - I*c)/a) + (I*a + c)*log((a*x + I*c)/a))/(2*a**2*c)

# %%
integrate(1 / (x**5 + 2 * x + 1), x)
# Out:
# RootSum(11317*_t**5 - 1280*_t**3 - 320*_t**2 - 30*_t - 1, Lambda(_t, _t*log(-5794304*_t**4/625 + 724288*_t**3/625 + 564824*_t**2/625 + 93237*_t/625 + x + 4096/625)))

# %%
integrate(asin(x), x)
# Out:
# x*asin(x) + sqrt(1 - x**2)

# %%
integrate(x**2 / sqrt(a**2 + x**2), x)
# Out:
# -a**2*asinh(x/a)/2 + a*x*sqrt(1 + x**2/a**2)/2

# %%
integrate(exp(a * x) * cos(b * x), x).simplify()
# Out:
# Piecewise((x, Eq(a, 0) & Eq(b, 0)), ((b*x*exp(I*b*x) + I*cos(b*x))*exp(-I*b*x)/(2*b), Eq(a, -I*b)), ((b*x*exp(-I*b*x) - I*cos(b*x))*exp(I*b*x)/(2*b), Eq(a, I*b)), ((a*cos(b*x) + b*sin(b*x))*exp(a*x)/(a**2 + b**2), True))

# %%
integrate(sqrt(x) * sqrt(1 + x), x)
# Out:
# Piecewise((-acosh(sqrt(x + 1))/4 + (x + 1)**(5/2)/(2*sqrt(x)) - 3*(x + 1)**(3/2)/(4*sqrt(x)) + sqrt(x + 1)/(4*sqrt(x)), Abs(x + 1) > 1), (I*asin(sqrt(x + 1))/4 - I*(x + 1)**(5/2)/(2*sqrt(-x)) + 3*I*(x + 1)**(3/2)/(4*sqrt(-x)) - I*sqrt(x + 1)/(4*sqrt(-x)), True))

# %%
integrate(sqrt(x) * sqrt(1 + x) * sqrt(2 + x), x)
# Out:
# Integral(sqrt(x)*sqrt(x + 1)*sqrt(x + 2), x)

# %%
integrate(exp(-x**2), x)
# Out:
# sqrt(pi)*erf(x)/2

# %%
integrate(log(1 + x)**2 / x, x)
# Out:
# Integral(log(x + 1)**2/x, x)

# %%
integrate(log(log(x)), x)
# Out:
# x*log(log(x)) - li(x)

# %%
integrate(tan(x)**n, x)
# Out:
# Integral(tan(x)**n, x)

# %%
integrate(p(x) * log(p(x)), p(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-133b58204bd4> in <module>
# ----> 1 integrate(p(x) *log(p(x)), p(x))
#
# TypeError: 'Symbol' object is not callable

# %%
integrate(x**4 + x**2 + 1, (x, 1, 3))
# Out:
# 886/15

# %%
plot(-12 + 19 * x - 8 * x**2 + x**3, (x, 1, 3))

# %%
integrate(a * x**2 + b * x + c, (x, -2, 2))
# Out:
# 16*a/3 + 4*c

# %%
integrate(x**n + n * x, (x, 0, a)).simplify()
# Out:
# Piecewise(((a**2*n*(n + 1)/2 + a**(n + 1))/(n + 1), (n > -oo) & (n < oo) & Ne(n, -1)), (a**2*n/2 + log(a) + oo, True))

# %%
integrate(1 / (x**4 + x**2 + 1), (x, 0, oo))
# Out:
# sqrt(3)*pi/6

# %%
plot(1 / (x**4 + x**2 + 1), (x, 0, 5))

# %%
integrate((4 * x**2 - 7 * x - 12) / ((x + 2) * (x - 3)), (x, -1, 2))
# Out:
# 12 - 21*log(4)/5

# %%
plot((4 * x**2 - 7 * x - 12) / ((x + 2) * (x - 3)), (x, -1, 2))

# %%
integrate((1 + x**3) * cbrt(x), (x, -1, 1))
# Out:
# 51/52 + 27*(-1)**(1/3)/52

# %%
plot((1 + x**3) * cbrt(x), (x, -1, 1))

# %%
integrate(1 / ((2 + x**2) * sqrt(4 + 3 * x**2)), (x, -oo, oo)).simplify()
# Out:
# acosh(sqrt(6)/2)

# %%
plot(1 / ((2 + x**2) * sqrt(4 + 3 * x**2)), (x, -7, 7))

# %%
integrate(cos(2 * x)**4, (x, 0, pi))
# Out:
# 3*pi/8

# %%
plot(cos(2 * x)**4, (x, 0, pi / 2))

# %%
integrate(x**2 * sin(2 * x), (x, 0, 2 * pi))
# Out:
# -2*pi**2

# %%
plot(x**2 * sin(2 * x), (x, 0, 2 * pi))

# %%
integrate(x**5 * log(x), (x, 1, 2))
# Out:
# -7/4 + 32*log(2)/3

# %%
plot(x**5 * log(x), (x, 1, 2))

# %%
integrate(exp(-x + exp(-x)), (x, 0, oo))
# Out:
# -1 + E

# %%
plot(exp(-x + exp(-x)), (x, 0, 4))

# %%
integrate(x * cosh(x), (x, 0, a))
# Out:
# a*sinh(a) - cosh(a) + 1

# %%
integrate(exp(-I * x) / cosh(x)**3, (x, -oo, oo))
# Out:
# Integral(exp(-I*x)/cosh(x)**3, (x, -oo, oo))

# %%
integrate(x / sqrt(1 - x), (x, 0, 1))
# Out:
# 4/3

# %%
plot(x / sqrt(1 - x), (x, 0, 1), ylim=(0, 4))

# %%
limit(integrate(x / sqrt(1 - x), (x, 0, a)), a, 1)
# Out:
# 4/3

# %%
integrate(x**2 / sqrt(1 - x**4), (x, -1, 1)).simplify()
# Out:
# 2*sqrt(pi)*gamma(3/4)/gamma(1/4)

# %%
plot(x**2 / sqrt(1 - x**4), (x, -1, 1), ylim=(0, 2.5))

# %%
integrate(x * E**(-x), (x, 1, oo))
# Out:
# 2*exp(-1)

# %%
limit(integrate(x / E**x, (x, 1, a)), a, oo)
# Out:
# 2*exp(-1)

# %%
integrate(E**(-x**2), (x, -oo, oo))
# Out:
# sqrt(pi)

# %%
integrate(x**n, (x, 0, 1)).simplify()
# Out:
# Piecewise((1/(n + 1), (n > -oo) & (n < oo) & Ne(n, -1)), (oo, True))

# %%
integrate(E**(a * x), (x, 0, oo))
# Out:
# Piecewise((-1/a, Abs(arg(a) + pi) < pi/2), (Integral(exp(a*x), (x, 0, oo)), True))

# %%
integrate(sin(a * x) / x, (x, 0, oo))
# Out:
# Piecewise((pi/2, Eq(2*Abs(arg(a)), 0)), (Integral(sin(a*x)/x, (x, 0, oo)), True))

# %%
integrate(sin(t) / t, (t, a, b))
# Out:
# -Si(a) + Si(b)

# %%
integrate(cos(sin(x)**2), (x, 0, 2 * pi))
# Out:
# Integral(cos(sin(x)**2), (x, 0, 2*pi))

# %%
plot(cos(sin(x)**2), -1, (x, 0, 2 * pi), ylim=(0, 1), axis_center=(0, 0))

# %%
integrate(sqrt(x), (x, I, 3 - I))
# Out:
# 2*(3 - I)**(3/2)/3 - 2*I**(3/2)/3

# %%
integrate((I * exp(i * omega)) / (exp(I * omega) + Rational(1, 2)),
          (omega, 0, 2 * pi)).simplify()
# Out:
# 2*I*Integral(exp(i*omega)/(2*exp(I*omega) + 1), (omega, 0, 2*pi))

# %%
integrate(Piecewise((-x + 1, x < 0), (x, x < 1), (x**2, True)), x)
# Out:
# Piecewise((-x**2/2 + x, x < 0), (x**2/2, x < 1), (x**3/3 + 1/6, True))

# %%
plot(Piecewise((-x + 1, x < 0), (x, x < 1), (x**2, True)),
     integrate(Piecewise((-x + 1, x < 0), (x, x < 1), (x**2, True)), x),
     (x, -2, 2))

# %%
maxint = integrate(Max(sin(x), cos(x)), x)
maxint
# Out:
# Piecewise((sin(x), x <= pi/4), (-cos(x) + sqrt(2), x <= 5*pi/4), (sin(x) + 2*sqrt(2), True))

# %%
plot(maxint, Max(sin(x), cos(x)), (x, 0, 4 * pi))

# %%
integrate(Piecewise((1, x < 2), (x**3, x < 3), (0, True)), (x, 0, 3))
# Out:
# 73/4

# %%
integrate(Piecewise((1, x < 2), (x**3, x < 3), (0, True)), x)
# Out:
# Piecewise((x, x < 2), (x**4/4 - 2, x < 3), (73/4, True))

# %%
plot(integrate(Piecewise((1, x < 2), (x**3, x < 3), (0, True)), x),
     Piecewise((1, x < 2), (x**3, x < 3), (0, True)), (x, 0, 4))

# %%
integrate(floor(x**2), (x, 0, 3)).simplify()
# Out:
# Integral(floor(x**2), (x, 0, 3))

# %%
plot(floor(x**2), (x, 0, 3))

# %%
integrate(primepi(n), (n, 0, 100))
# Out:
# Integral(primepi(floor(n)), (n, 0, 100))

# %%
plot(primepi(x), (x, 0, 100))

# %%
integrate(Max(sin(x), cos(x)), (x, 0, a))
# Out:
# Piecewise((sin(a), a < 0), (sin(a) + sin(Min(pi/4, a)) - sin(Min(5*pi/4, a)) + cos(Min(pi/4, a)) - cos(Min(5*pi/4, a)), True))

# %%
plot(Max(sin(a), cos(a)), integrate(Max(sin(x), cos(x)), (x, 0, a)),
     (a, 0, 2 * pi))

# %%
integrate(diracdelta(x), (x, -oo, oo))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-155-41223b7cbe89> in <module>
# ----> 1 integrate(diracdelta(x), (x, -oo,oo))
#
# NameError: name 'diracdelta' is not defined

# %%
integrate(a * x**2 + b * x + c, x, x)
# Out:
# a*x**4/12 + b*x**3/6 + c*x**2/2

# %%
diff(integrate(a * x**2 + b * x + c, x, x), x, x)
# Out:
# a*x**2 + b*x + c

# %%
integrate(1 / (x**2 + 4), x, x, x)
# Out:
# x**2*atan(x/2)/4 - x*log(x**2 + 4)/2 + x/2 - atan(x/2)

# %%
diff(integrate(1 / (x**2 + 4), x, x, x), (x, 3)).simplify()
# Out:
# 1/(x**2 + 4)

# %%
integrate(x**2 * sin(y), y, x)
# Out:
# -x**3*cos(y)/3

# %%
diff(integrate(x**2 * sin(y), y, x), x, y)
# Out:
# x**2*sin(y)

# %%
integrate(exp(x) * cos(y), (x, 0, a), (y, 0, b))
# Out:
# exp(a)*sin(b) - sin(b)

# %%
integrate((x + y), (y, 0, 1), x)
# Out:
# x**2/2 + x/2

# %%
integrate(x**2 * y / (x + y), (x, 0, 3), (y, 1, 2))
# Out:
# -65*log(5)/4 - 4*log(2) + 39/8 + 20*log(4)

# %%
plot3d((x**2 * y) / (x + y), (x, 0, 3), (y, 1, 2))

# %%
integrate(y * sin(x * y), (x, 1, 4), (y, 0, pi))
# Out:
# 0

# %%
plot3d(y * sin(x * y), (x, 1, 4), (y, 0, pi))

# %%
integrate(8 - (3 * y) / 3 - (3 * x * y) / 3 + (x**2 * y) / 3 + (x**3 * y) / 3,
          (y, 2 * x**2, 4 + x**2), (x, -2, 2))
# Out:
# 20224/315

# %%
plot(2 * x**2, 4 + x**2, (x, -2, 2))

# %%
plot3d(8 - (3 * y) / 3 - (3 * x * y) / 3 + (x**2 * y) / 3 + (x**3 * y) / 3,
       (x, -5, 5), (y, -5, 5))

# %%
integrate(cos(z) * exp(x) * y, (x, 0, 1), (y, -1, 2), (z, 0, 3))
# Out:
# -3*sin(3)/2 + 3*E*sin(3)/2

# %%
integrate(a * b**2 - c / d**e, (a, 0, 1), (b, 1, 2), (c, 2, 3), (d, 3, 4),
          (e, 4, 5)).simplify()
# Out:
# 15*Integral(3**(-e)/(e - 1), (e, 4))/2 - 15*Integral(3**(-e)/(e - 1), (e, 5))/2 - 10*Integral(4**(-e)/(e - 1), (e, 4)) + 10*Integral(4**(-e)/(e - 1), (e, 5)) + 7/6

# %%
integrate(
    sin(theta) / r * (r**3 * sin(theta)**2 * sin(phi)), (psi, -pi, pi),
    (phi, 0, pi), (theta, 0, pi), (r, 0, r))
# Out:
# 16*pi*r**3/9

# %%
integrate(f(x).diff(x, x) + 2 * a * f(x).diff(x), x)
# Out:
# 2*a*f(x) + Derivative(f(x), x)

# %%
integrate(f(t), (t, 0, x))
# Out:
# Integral(f(t), (t, 0, x))

# %%
diff(integrate(f(t), (t, 0, x)), x)
# Out:
# f(x)

# %%
integrate(f(x, a), (x, 0, 1))
# Out:
# Integral(f(x, a), (x, 0, 1))

# %%
diff(integrate(f(x, a), (x, 0, 1)), a)
# Out:
# Integral(Derivative(f(x, a), a), (x, 0, 1))

# %%
p = Function("p")
q = Function("q")
diff(integrate(f(x, a), (x, p(a), q(a))), a)
# Out:
# -f(p(a), a)*Derivative(p(a), a) + f(q(a), a)*Derivative(q(a), a) + Integral(Derivative(f(x, a), a), (x, p(a), q(a)))

# %%
laplace_transform(integrate(f(u), (u, 0, t)), t, s)
# Out:
# LaplaceTransform(Integral(f(u), (u, 0, t)), t, s)

# %%
integrate(x**n, (x, 0, 1)).simplify()
# Out:
# Piecewise((1/(n + 1), (n > -oo) & (n < oo) & Ne(n, -1)), (oo, True))

# %%
integrate(exp(-a * x**2), (x, -oo, oo))
# Out:
# Piecewise((sqrt(pi)/sqrt(a), Abs(arg(a)) <= pi/2), (Integral(exp(-a*x**2), (x, -oo, oo)), True))

# %%
integrate(floor(x), x)
# Out:
# Integral(floor(x), x)

# %%
plot(1 + sqrt(9 - x**2), (x, -3, 0))

# %%
integrate(1 + sqrt(9 - x**2), (x, -3, 0))
# Out:
# 3 + 9*pi/4

# %%
plot(sin(x)**2 * cos(x)**4, (x, -pi, pi))

# %%
integrate(sin(x)**2 * cos(x)**4, (x, -pi, pi))
# Out:
# pi/8

# %%
plot(sin(x), (x, -pi, pi))

# %%
integrate(Abs(sin(x)), (x, -pi, pi))
# Out:
# 4

# %%
integrate(0 - sin(x), (x, -pi, 0)) + integrate(sin(x) + 0, (x, 0, pi))
# Out:
# 4

# %%
plot(5 * x - x**2, x, (x, 0, 4))

# %%
integrate((5 * x - x**2) - (x), (x, 0, 4))
# Out:
# 32/3

# %%
solve(Eq(y, 2 / (1 + x**4)) and Eq(y, x**2), (x, y))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-214-b70ec5b84344> in <module>
# ----> 1 solve(Eq(y , 2/(1 + x**4))and  Eq( y ,x**2), (x, y))
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\core\relational.py in __nonzero__(self)
#     374
#     375     def __nonzero__(self):
# --> 376         raise TypeError("cannot determine truth value of Relational")
#     377
#     378     __bool__ = __nonzero__
#
# TypeError: cannot determine truth value of Relational

# %%
integrate(2 / (x**4 + 1) - x**2, (x, -1, 1))
# Out:
# -2/3 - sqrt(2)*log(2 - sqrt(2))/2 + sqrt(2)*log(sqrt(2) + 2)/2 + sqrt(2)*pi/2

# %%
integrate(cos(x) - (1 - (2 * x) / pi), (x, 0, pi / 2)) + integrate(
    (1 - (2 * x) / pi) - cos(x), (x, pi / 2, pi))
# Out:
# 2 - pi/2

# %%
integrate(x - Rational(1, 8) * x,
          (x, 0, 1)) + integrate(1 / x**2 - Rational(1, 8) * x, (x, 1, 2))
# Out:
# 3/4

# %%
integrate(Min(x, 1 / x**2) - Rational(1, 8) * x, (x, 0, 2))
# Out:
# 3/4

# %%
integrate(pi * (sin(x)**2)**2, (x, 0, pi))
# Out:
# 3*pi**2/8

# %%
integrate(2 * pi * x * (x * (x - 1)**2), (x, 0, 1))
# Out:
# pi/15

# %%
w = sqrt(1 + diff(x**3, x)**2)
integrate(2 * pi * x * w, (x, 0, 1))
# Out:
# 2*pi*(asinh(3)/12 + sqrt(10)/4)

# %%
w = sqrt(1 + diff(sqrt(x**2 + 1), x)**2)
integrate(2 * pi * sqrt(x**2 + 1) * w, (x, -sqrt(3), sqrt(3)))
# 运行很久都没出
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-223-703d2bccddb0> in <module>
#       1 w = sqrt(1 + diff(sqrt(x**2 + 1), x)**2)
#       2 integrate(2*pi*sqrt(x**2 + 1)*
# ----> 3    w, (x, -sqrt(3), sqrt(3)))
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\integrals\integrals.py in integrate(*args, **kwargs)
#    1520
#    1521     if isinstance(integral, Integral):
# -> 1522         return integral.doit(**doit_flags)
#    1523     else:
#    1524         new_args = [a.doit(**doit_flags) if isinstance(a, Integral) else a
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\integrals\integrals.py in doit(self, **hints)
#     462         if reps:
#     463             undo = dict([(v, k) for k, v in reps.items()])
# --> 464             did = self.xreplace(reps).doit(**hints)
#     465             if type(did) is tuple:  # when separate=True
# ...

# %%
w = sqrt(1 + diff(1 / x, x)**2)
integrate(2 * pi * (4 - x) * w, (x, 1, 3))
# Out:
# -2*pi*(gamma(-1/4)*hyper((-1/2, -1/4), (3/4,), -1)/gamma(3/4) - sqrt(2)/2 + log(1 + sqrt(2))/2) + 2*pi*(gamma(-1/4)*hyper((-1/2, -1/4), (3/4,), 81*exp_polar(I*pi))/(3*gamma(3/4)) - sqrt(82)/2 + asinh(1/9)/2)

# %%
plot3d_parametric_surface(
    cos(theta) * (x - 4) + 4, 1 / x,
    sin(theta) * (x - 4), (x, 1, 3), (theta, 0, 2 * pi))

# %%
f = x**4 / 8 + 1 / (4 * x**2)
plot(f, -1, (x, 1, 2), ylim=(0, 2), axis_center=(1, 0))

# %%
ds = sqrt(1 + diff(f, x)**2).simplify()
ds
# Out:
# sqrt(x**6 + 2 + x**(-6))/2

# %%
integrate(ds, (x, 1, 2)).simplify()
# Out:
# 33/16

# %%
f = sqrt(x - x**2) + asin(sqrt(x))
plot(f, (x, 0, 1))

# %%
f = sqrt(x - x**2) + asin(sqrt(x))
ds = sqrt(1 + diff(f, x)**2).simplify()
ds.simplify()
# Out:
# sqrt(4 + (2*x**(3/2)*sqrt(1 - x) - sqrt(x)*sqrt(1 - x) - sqrt(-x**2 + x))**2/(x**2*(x - 1)**2))/2

# %%
integrate(ds, (x, 0, 1))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-247-e14494ca3e70> in <module>
# ----> 1 integrate(ds, (x, 0, 1))
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\integrals\integrals.py in integrate(*args, **kwargs)
#    1520
#    1521     if isinstance(integral, Integral):
# -> 1522         return integral.doit(**doit_flags)
#    1523     else:
#    1524         new_args = [a.doit(**doit_flags) if isinstance(a, Integral) else a
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\integrals\integrals.py in doit(self, **hints)
#     462         if reps:
#     463             undo = dict([(v, k) for k, v in reps.items()])
# --> 464             did = self.xreplace(reps).doit(**hints)
#     465             if type(did) is tuple:  # when separate=True
#     466                 did = tuple([i.xreplace(undo) for i in did])
#
# ...

# %%
Array((n * pi**Rational(n, 2)) / (2 * gamma(2 + Rational(n, 2)))
      for n in range(1, 11))
# Out:
# [2/3, pi/2, 4*pi/5, pi**2/3, 8*pi**2/21, pi**3/8, 16*pi**3/135, pi**4/30, 32*pi**4/1155, pi**5/144]

# %%
integrate(cos(x)**4 * sin(x) / pi, (x, 0, pi))
# Out:
# 2/(5*pi)

# %%
plot(cos(x)**4 * sin(x), 2 / (5 * pi), (x, 0, pi))

# %%
integrate(x + y, (x, y / 2, y / 2 + 1),
          (y, 0, 2)) / integrate(1, (x, y / 2, y / 2 + 1), (y, 0, 2))
# Out:
# 2

# %%
a = integrate(2 * x, (x, 0, 1))
a
# Out:
# 1

# %%
xcentroid = (1 / a) * integrate(x, (y, 0, 2 * x), (x, 0, 1))
xcentroid
# Out:
# 2/3

# %%
ycentroid = (1 / a) * integrate(y, (y, 0, 2 * x), (x, 0, 1))
ycentroid
# Out:
# 2/3

# %%
from sympy.stats import *
X = Normal("x", 0, 1)
pdf = density(X)(z).simplify()
pdf
# Out:
# sqrt(2)*exp(-z**2/2)/(2*sqrt(pi))

# %%
def Boolean(x):
    if (x - 2)**2 < 1:
        return pdf
    else:
        return 0


integrate(Boolean(x), (x, -oo, oo))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-275-7ce4acdd11e6> in <module>
#       4     else:
#       5         return 0
# ----> 6 integrate(Boolean(x), (x, -oo, oo))
#
# <ipython-input-275-7ce4acdd11e6> in Boolean(x)
#       1 def Boolean(x):
# ----> 2     if (x-2)**2<1:
#       3         return pdf
#       4     else:
#       5         return 0
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\core\relational.py in __nonzero__(self)
#     374
#     375     def __nonzero__(self):
# --> 376         raise TypeError("cannot determine truth value of Relational")
#     377
#     378     __bool__ = __nonzero__
#
# TypeError: cannot determine truth value of Relational

# %%
P((X - 2)**2 < 1)
# Out:
# -erf(sqrt(2)/2)/2 + erf(3*sqrt(2)/2)/2

# %%
integrate(Rational(5, 2) * E**(-5 * t / 2), (t, 4, oo))
# Out:
# exp(-10)

# %%
integrate(Rational(5, 2) * E**(-5 * t / 2), (t, 0, 2))
# Out:
# 1 - exp(-5)

# %%
from sympy.stats import *
x = Exponential("x", Rational(5, 2))
P(x > 4)
# Out:
# exp(-10)

# %%
from sympy.stats import *
x = Exponential("x", Rational(5, 2))
P(x < 2)
# Out:
# 1 - exp(-5)

# %%
(1 / (sigma * sqrt(2 * pi))) * integrate(exp(-((x - mu)**2 / (2 * sigma**2))),
                                         (x, mu - 2 * sigma, mu + 2 * sigma))
# Out:
# erf(sqrt(2))

# %%
from sympy.stats import *
x=Normal("x",mu,sigma)
P(mu-2*sigma<= x && x<= mu+2*sigma)
# 搞不懂
# Out:
#   File "<ipython-input-18-3cb8b0ebe513>", line 3
#     P(mu-2*sigma<= x && x<= mu+2*sigma)
#                       ^
# SyntaxError: invalid syntax

# %%
from sympy.stats import *
tr=Piecewise(
(density(Normal("x",0,1))(z).simplify(),x<=2),
(0,True)
)
plot(
density(Normal("x",0,1))(z).simplify(),
Piecewise(
(density(Normal("x",0,1))(z).simplify(),z<=2),
(0,True)
),
    (z,-3,3)
)

# %%
pdf=density(Cauchy("x",0,1))(x)
pdf
# Out:
# 1/(pi*(x**2 + 1))

# %%
integrate(sqrt(Abs(x))* pdf, (x, -oo, oo))
# Out:
# sqrt(2)

# %%
X=Cauchy("X",0,1)
E(sqrt(Abs(X)))
# Out:
# sqrt(2)

# %%
integrate(sin(x)/log(x), x)
# Out:
# Integral(sin(x)/log(x), x)

# %%
f= 1/(2 + sin(x))
plot(f, integrate(f, x), (x, 0, 2 *pi))

# %%
integrate(1/sqrt(a**2 - x**2), x)
# Out:
# Piecewise((-I*acosh(x/a), Abs(x**2)/Abs(a**2) > 1), (asin(x/a), True))

# %%
diff(integrate(1/sqrt(a**2 - x**2), x),x).simplify()
# Out:
# Piecewise((-I/(a*sqrt(-1 + x**2/a**2)), Abs(x**2/a**2) > 1), (1/(a*sqrt(1 - x**2/a**2)), True))

# %%
integrate(1 + (x + 1)**3, x)
# Out:
# x**4/4 + x**3 + 3*x**2/2 + 2*x

# %%
integrate(expand(1 + (x + 1)**3), x)
# Out:
# x**4/4 + x**3 + 3*x**2/2 + 2*x

# %%
integrate(x**n, x)
# Out:
# Piecewise((x**(n + 1)/(n + 1), Ne(n, -1)), (log(x), True))

# %%
integrate(x**-1, x)
# Out:
# log(x)

# %%
integrate(t**n, (t, 0, x)).simplify()
# Out:
# Piecewise((x**(n + 1)/(n + 1), (n > -oo) & (n < oo) & Ne(n, -1)), (log(x) + oo, True))

# %%
f=Function("f")
integrate(f(x) + f(x).diff(x), x)
# Out:
# Integral(f(x) + Derivative(f(x), x), x)

# %%
f=Function("f")
integrate(f(x),x)+  integrate(f(x).diff(x), x)
# Out:
# f(x) + Integral(f(x), x)

# %%
integrate(1/(2 + cos(x)), (x, 0, 2*pi))
# Out:
# 2*sqrt(3)*pi/3

# %%
expr = integrate(1/(2 + cos(x)), x)
expr
# Out:
# 2*sqrt(3)*(atan(sqrt(3)*tan(x/2)/3) + pi*floor((x/2 - pi/2)/pi))/3

# %%
x=symbols("x")
plot(expr, (x, 0, 2 *pi))

# %%
k=symbols("k",integer=True)
integrate(k *cos(k *x), (x, -pi, pi))
# Out:
# Piecewise((0, Ne(k, 0)), (2*pi*k, True))

# %%
integrate(besselj(2, x)/(1 + x**2), (x, 0, 1))
# Out:
# Integral(besselj(2, x)/(x**2 + 1), (x, 0, 1))

# %%
integrate(besselj(2, x)/(1 + x**2), (x, 0, oo)).simplify()
# Out:
# hyper((1,), (1/2, 5/2), 1/4)/3 - pi*besseli(0, 1)/2 + pi*besseli(1, 1)

# %%
integrate((x**2 - y**2)/(x**2 + y**2)**2, (x, 0, 1), (y, 0, 1))
# Out:
# -pi/4

# %%
integrate((x**2 - y**2)/(x**2 + y**2)**2, (y, 0, 1), (x, 0, 1))
# Out:
# pi/4

# %%
f= 1/x
v = integrate(pi* f**2, (x, 1, a))
v
# Out:
# pi - pi/a

# %%
s= integrate(2 *pi* f* sqrt(1 + diff(f, x)**2), (x, 1, a)).simplify()
s
# Out:
# pi*asinh(a**2) - pi*log(1 + sqrt(2)) + sqrt(2)*pi - pi*sqrt(a**4 + 1)/a**2

# %%
limit(v,a,oo)
# Out:
# pi

# %%
limit(s,a,oo)
# Out:
# oo

# %%
Array(integrate(
   product(
       sin(x/(2*k + 1))/(x/(2*k + 1)), (k, 0, max1)
   ), 
   (x, 0, oo)) for max1 in range(1, 7))
# die

# %%
integrate(
   product(
       sin(x/(2*k + 1))/(x/(2*k + 1)), (k, 0,8)
   ), 
   (x, 0, oo))
# die
# Out:
# ---------------------------------------------------------------------------
# MellinTransformStripError                 Traceback (most recent call last)
# D:\Program Files\Python3.7\lib\site-packages\sympy\integrals\meijerint.py in my_imt(F, s, x, strip)
#    1503             return inverse_mellin_transform(F, s, x, strip,
# -> 1504                                             as_meijerg=True, needeval=True)
#    1505         except MellinTransformStripError:
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\integrals\transforms.py in inverse_mellin_transform(F, s, x, strip, **hints)
#     873     """
# --> 874     return InverseMellinTransform(F, s, x, strip[0], strip[1]).doit(**hints)
#     875
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\integrals\transforms.py in doit(self, **hints)
#     122                 return self._compute_transform(self.function,
# --> 123                     self.function_variable, self.transform_variable, **hints)
# ...

# %%
integrate(log((1 + sqrt(1 + 4* x))/2)/x, (x, 0, 1))
# Out:
# Integral(log(sqrt(4*x + 1)/2 + 1/2)/x, (x, 0, 1))
