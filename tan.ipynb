# %% [markdown]
# # Examples

# %% [markdown]
# ## Basic Examples

# %%
from sympy import *
tan(pi/6)
# Out:
# sqrt(3)/3

# %%
from sympy import *
tan(rad(30))
# Out:
# sqrt(3)/3

# %%
from sympy import *
from sympy.abc import x
plot(tan(x), (x, 0, 2*pi), ylim=(-7, 7))

# %%
# complexplot3D
from sympy import *
from sympy.functions import *
from sympy.plotting import *
from sympy.abc import x, y
plot3d(
    Abs(tan(x+I*y)),
    (x, -pi, pi), (y, -2, 2)
)

# %%
from sympy import *
from sympy.abc import x
tan(x).series(x0=0, n=11)  # 此处 Mathematica 是 Series[Tan[x], {x, 0, 10}]
# Out:
# x + x**3/3 + 2*x**5/15 + 17*x**7/315 + 62*x**9/2835 + O(x**11)

# %%
from sympy import *
from sympy.abc import x
tan(x).series(x0=pi/2, n=6)  # 此处 Mathematica 是 Series[Tan[x], {x, 0, 10}]
# Out:
# -1/(x - pi/2) - pi/6 + (x - pi/2)**3/45 + 2*(x - pi/2)**5/945 + x/3 + O((x - pi/2)**6, (x, pi/2))

# %% [markdown]
# ## Scope

# %% [markdown]
# ### Numerical Evaluation

# %%
from sympy import *
tan(1.2)
# Out:
# 2.57215162212632

# %%
from sympy import *
tan(Rational(12, 10)).evalf(n=50)  # 和 Mathematica 一致
# Out:
# 2.5721516221263189354099942360333639565294093060434

# %%
from sympy import *
tan(1.20000000000000000000000)
# Out:
# 2.57215162212632

# %%
from sympy import *
tan(2.5 + I)
# Out:
# -0.237013830916271 + 0.896437917127862*I

# %% [markdown]
# #### 没有测时间函数

# %%
from sympy import *
tan(AccumBounds(0, pi/3))
# Out:
# AccumBounds(0, sqrt(3))

# %%
from sympy import *
Array([1.2, 1.5, 1.8]).applyfunc(tan)
# Out:
# [2.57215162212632, 14.1014199471717, -4.28626167462806]

# %%
from sympy import *
u, v = symbols("u v")
Matrix([[pi, u], [v, pi/3]]).applyfunc(tan)
# Out:
# Matrix([
# [     0,  tan(u)],
# [tan(v), sqrt(3)]])

# %% [markdown]
# ### Specific Values

# %%
from sympy import *
Array([pi/6*n for n in range(-2, 3)]).applyfunc(tan)
# Out:
# [-sqrt(3), -sqrt(3)/3, 0, sqrt(3)/3, sqrt(3)]

# %%
from sympy import *
tan(oo)
# Out:
# AccumBounds(-oo, oo)

# %%
from sympy import *
tan(zoo)
# 这缩写简直了
# Out:
# nan

# %%
from sympy import *
from sympy.assumptions import *
m = symbols("m", integer=True)
tan(pi*m).simplify()
# Out:
# 0

# %%
from sympy import *
x = symbols("x")
solveset(Eq(tan(x), 0), x, domain=Interval.open(-pi/2, pi/2))
# Out:
# FiniteSet(0)

# %%
from sympy import *
from sympy.plotting import *
plot(tan(x), (x, -pi/2, pi/2), ylim=(-7, 7))
# 不会加点

# %%
from sympy import *
x = symbols("x")
solveset(Eq(diff(sin(x), x), 0), x, domain=Interval.open(0, pi))
# Out:
# FiniteSet(pi/2)

# %%
from sympy import *
from sympy.assumptions import *
m = symbols("m", integer=True)
tan(pi*(Rational(1, 2) + m)).simplify()
# 应该是 infty
# Out:
# tan(pi*(m + 1/2))

# %%
from sympy import *
tan(pi/5)
# Out:
# sqrt(5 - 2*sqrt(5))

# %%
from sympy import *
tan(pi/8)
# Out:
# -1 + sqrt(2)

# %% [markdown]
# ### Visualization

# %%
from sympy import *
from sympy.plotting import *
plot(tan(x), (x, -pi, pi), ylim=(-7, 7))

# %% [markdown]
# #### sympy 没有等高线绘图函数，等大神补充

# %% [markdown]
# #### sympy 没有极坐标绘图函数，等大神补充

# %% [markdown]
# ## Function Properties

# %%
from sympy import *
from sympy.abc import *
# 好像没定义域函数
solveset(tan(x) < oo, x, domain=Reals)
# Out:
# ConditionSet(x, tan(x) < oo, Reals)

# %%
from sympy import *
tan(AccumBounds(-oo, oo))
# Out:
# AccumBounds(-oo, oo)

# %%
from sympy import *
periodicity(tan(x), x)
# Out:
# pi

# %%
from sympy import *
tan(-x)
# Out:
# -tan(x)

# %%
from sympy import *
Eq(tan(conjugate(z)), conjugate(tan(z)))
# Out:
# True

# %% [markdown]
# ### Differentiation

# %%
from sympy import *
diff(tan(x), x).simplify().rewrite(sec)
# Out:
# sec(x)**2

# %%
from sympy import *
from sympy.abc import *
Array(range(1, 5)).applyfunc(lambda i: diff(tan(x), x, i))
# Out:
# [tan(x)**2 + 1, 2*(tan(x)**2 + 1)*tan(x), 2*(tan(x)**2 + 1)*(3*tan(x)**2 + 1), 8*(tan(x)**2 + 1)*(3*tan(x)**2 + 2)*tan(x)]

# %%
from sympy.abc import *
from sympy import *
from sympy.plotting import *
plot(*Array(range(1, 5)).applyfunc(lambda i: diff(tan(x), x, i)),
     (x, -pi, pi), ylim=(-100, 150))

# %%
from sympy import *
from sympy.abc import *
n = symbols("n", integer=True, positive=True)
diff(tan(x), x, n)
# Out:
# 0

# %% [markdown]
# ### Integration

# %%
from sympy import *
integrate(tan(x), x)
# Out:
# -log(cos(x))

# %%
from sympy import *
integrate(tan(x), (x, 0, pi))
# 没有主值选项
# Out:
# nan

# %%
from sympy import *
integrate(tan(x)*cos(x), x)
# Out:
# -cos(x)

# %%
from sympy import *
from sympy.abc import *
integrate(tan(z)**a, z)
# MMA 算出来了
# Out:
# Integral(tan(z)**a, z)

# %% [markdown]
# ### Series Expansions

# %%
from sympy import *
tan(x).series(n=8)
# Out:
# x + x**3/3 + 2*x**5/15 + 17*x**7/315 + O(x**8)

# %%
from sympy.abc import *
from sympy import *
plot(*Array([3, 5, 7]).applyfunc(lambda m: tan(x).series(n=m).removeO()),
     tan(x), (x, -pi/2, pi/2), ylim=(-6, 6))

# %% [markdown]
# #### 不会级数系数列表

# %%
from sympy import *
from sympy.abc import z
fourier_transform(tan(z), z, 1).simplify()
# 和 MMA 不一样
# Out:
# FourierTransform(tan(z), z, 1)

# %%
from sympy import *
tan(x).series(n=7).subs(x, tan(x).series(n=7)).expand()
# Out:
# x + 2*x**3/3 + 3*x**5/5 + O(x**7)

# %% [markdown]
# ### Integral Transforms

# %%
from sympy import *
fourier_transform(sin(t), t, k)
# ？？？
# Out:
# 0

# %%
from sympy import *
laplace_transform(sin(t), t, s)[0]
# Out:
# 1/(s**2 + 1)

# %%
from sympy import *
mellin_transform(sin(x), x, s)[0]
# Out:
# 2**s*sqrt(pi)*gamma(s/2 + 1/2)/(2*gamma(1 - s/2))

# %% [markdown]
# ### Function Identities and Simplifications

# %%
from sympy import *
expand_trig(tan(2*x)).rewrite(sin).radsimp()
# 2sin(x)cos(x)
# Out:
# 4*sin(x)**2*sin(2*x)/(-4*sin(x)**4 + sin(2*x)**2)

# %%
from sympy import *
expand_trig(tan(x+y)).rewrite(sin).radsimp()
# Out:
# (2*sin(x)**2*sin(2*y) + 2*sin(2*x)*sin(y)**2)/(-4*sin(x)**2*sin(y)**2 + sin(2*x)*sin(2*y))

# %%
from sympy import *
expand_trig(tan(4*x))
# Out:
# (-4*tan(x)**3 + 4*tan(x))/(tan(x)**4 - 6*tan(x)**2 + 1)

# %%
from sympy import *
expand_trig(tan(4*x)).simplify()
# 好像没有 TrigReduce
# Out:
# tan(4*x)

# %%
from sympy import *
# 好像没有 TrigFactor
# Out:
# sin(x) + cos(y)

# %%
from sympy import *
import sympy
x, y = symbols('x,y', real=True)
expand_complex(tan(x+I*y))
# Out:
# sin(2*x)/(cos(2*x) + cosh(2*y)) + I*sinh(2*y)/(cos(2*x) + cosh(2*y))

# %%
from sympy import *
from sympy.abc import *
tan(z).rewrite(exp).expand()
# Out:
# I/(exp(2*I*z) + 1) - I*exp(I*z)/(exp(I*z) + exp(-I*z))

# %% [markdown]
# ### Function Representations

# %%
from sympy import *
cot(pi/2-x)
# Out:
# tan(x)

# %%
from sympy import *
# 不熟悉 JacobiSC
# Out:
# tan(x)

# %%
# 不熟悉 JacobiSN

# %%
from sympy import *
# 没有球面谐函数？

# %%
from sympy import *
(mathieus(1, 0, z)/mathieuc(1, 0, z)).simplify()
# 没有约化函数
# Out:
# tan(z)

# %% [markdown]
# ## Applications

# %%
from sympy import *
from sympy.plotting import *
plot3d(re(tan(x + I*y)), (x, 0, 2*pi), (y, 0, 3))

# %%
from sympy import *
z = symbols('z')
w = symbols('w', cls=Function)
dsolve(
    Eq(
        Derivative(w(z), z, z)-w(z)**2-1,
        0
    )
)
# sympy 解不出
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-88-6126769c018b> in <module>
#       5     Eq(
#       6         Derivative(w(z),z,z)-w(z)**2-1,
# ----> 7         0
#       8         )
#       9     )
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\solvers\ode.py in dsolve(eq, func, hint, simplify, ics, xi, eta, x0, n, **kwargs)
#     644         hints = _desolve(eq, func=func,
#     645             hint=hint, simplify=True, xi=xi, eta=eta, type='ode', ics=ics,
# --> 646             x0=x0, n=n, **kwargs)
#     647         eq = hints.pop('eq', eq)
#     648         all_ = hints.pop('all', False)
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\solvers\deutils.py in _desolve(eq, func, hint, ics, simplify, **kwargs)
#     242                 str(eq) + " is not a solvable differential equation in " + str(func))
#     243         else:
# ...

# %% [markdown]
# #### The tangent function conformally maps a parabola into the unit disk:

# %% [markdown]
# #### Pursuit curve in the reference frame of the predator with prey moving half as fast along a line:

# %% [markdown]
# ## Properties & Relations

# %%
from sympy import *
tan(x+2*pi)
# Out:
# tan(x)

# %%
from sympy import *
tan(-x)
# Out:
# -tan(x)

# %%
from sympy import *
tan(I*x)
# Out:
# I*tanh(x)

# %%
from sympy import *
1/tan(x).rewrite(cot)
# Out:
# cot(x)

# %% [markdown]
# #### 无 TrigFactorList

# %%
from sympy import *
(tan(z)+cot(z))
# 不能化简
# Out:
# sec(z)/sec(z - pi/2) + sec(z - pi/2)/sec(z)

# %%
from sympy import *
k = symbols("k", integer=True)
x = symbols("x")
tan(k*pi-x).simplify()
# 无法化简
# Out:
# tan(pi*k - x)

# %%
from sympy import *
Array([tan(atan(z)), tan(2*atan(z)), tan(3*atan(z))])
# FunctionExpand 好像没用
# Out:
# [z, tan(2*atan(z)), tan(3*atan(z))]

# %%
from sympy import *
solveset(Eq(tan(z)**2-2*tan(z+pi/4), 4))
# Out:
# Union(ImageSet(Lambda(_n, 2*_n*pi + 2*atan(CRootOf(3*_r**6 + 2*_r**5 - 11*_r**4 - 8*_r**3 + 11*_r**2 + 2*_r - 3, 0)) + 2*pi), Integers), ImageSet(Lambda(_n, 2*_n*pi + 2*atan(CRootOf(3*_r**6 + 2*_r**5 - 11*_r**4 - 8*_r**3 + 11*_r**2 + 2*_r - 3, 1))), Integers))

# %%
from sympy import *
α, x, β = symbols("α x β")
solveset(Eq(tan(α*x+β), 0), x)
# sympy 求不出
# Out:
# ConditionSet(x, Eq(I*(exp(I*(-x*α - β)) - exp(I*(x*α + β)))/(exp(I*(-x*α - β)) + exp(I*(x*α + β))), 0), Reals)

# %%
from sympy import *
α, x, β = symbols("α x β")
solveset(Eq(cot(α*x+β), 0), x)
# solveset(Eq(1/tan(α*x+β),0),x)
# 写成 solveset(Eq(1/tan(α*x+β),0),x)
# sympy 求不出
# issue 已提
# Out:
# ConditionSet(x, Eq(I*(exp(I*(-x*α - β)) + exp(I*(x*α + β)))/(-exp(I*(-x*α - β)) + exp(I*(x*α + β))), 0), Reals)

# %% [markdown]
# #### 不知道 sympy 有没有求数值解工具

# %%
from sympy import *
integrate(tan(z)**a, z)
# Out:
# Integral(tan(z)**a, z)

# %%
from sympy import *
(mathieus(1, 0, z)/mathieuc(1, 0, z)).simplify()
# Out:
# tan(z)

# %%
from sympy import *
# JacobiSC

# %%
from sympy import *
# JacobiCS

# %%
from sympy import *
# JacobiSN

# %%
from sympy import *
# JacobiNS

# %%
from sympy import *
(hyper([], [Rational(3, 2)], -z)/hyper([], [Rational(1, 2)], -z)).simplify()
# Out:
# tan(2*sqrt(z))/(2*sqrt(z))

# %%
from sympy import *
(meijerg([[], []], [[Rational(1, 2)], [0]], z) /
 meijerg([[], []], [[-Rational(1, 2)], [0]], z)).simplify()
# Out:
# sqrt(z)*tan(2*sqrt(z))

# %%
from sympy import *
Array(range(1, 6)).applyfunc(lambda k: residue(tan(z)**k, z, pi/2))
# Out:
# [-1, 0, 1, 0, -1]

# %%
from sympy import *
# sympy 应该无法在复平面积分

# %%
from sympy import *
# Attributes 函数不清楚
# NumericQ 函数不清楚

# %% [markdown]
# ## Neat Example

# %%
from sympy import *
product(tan(z+k*pi/n), (k, 1, n-1)).simplify()
# sympy 解不出
# Out:
# Product(tan(pi*k/n + z), (k, 1, n - 1))

# %%
from sympy import *
integrate(tan(acot(z)), z)
# Out:
# log(z)

# %%
from sympy import *
# no ArrayPlot

# %%
from sympy import *
tan(pi/2**12).rewrite(sqrt).simplify()
# Out:
# sqrt(2 - sqrt(sqrt(sqrt(sqrt(sqrt(sqrt(sqrt(sqrt(sqrt(sqrt(2) + 2) + 2) + 2) + 2) + 2) + 2) + 2) + 2) + 2))/sqrt(sqrt(sqrt(sqrt(sqrt(sqrt(sqrt(sqrt(sqrt(sqrt(sqrt(2) + 2) + 2) + 2) + 2) + 2) + 2) + 2) + 2) + 2) + 2)

# %%
from sympy import *
result = []
j = 0
for i in continued_fraction_iterator(tan(1)):
    j += 1
    result.append(i)
    if(j > 21):
        break
result
# 额外加了条件
# continued_fraction 无法处理 tan(1)
# Out:
# [1, 1, 1, 3, 1, 5, 1, 7, 1, 9, 1, 11, 1, 13, 1, 15, 1, 17, 1, 19, 1, 21]

# %%
from sympy import *
tan(1).is_AlgebraicNumber
# Out:
# False

# %%
from sympy import *
from sympy.plotting import *
plot3d(tan(y**2-x**3+3*x-3), (x, -2, 2), (y, -2, 2))
# 不知道怎么更改 z 的范围
