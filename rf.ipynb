# %% [markdown]
# # Examples

# %% [markdown]
# ## Basic Examples

# %%
from sympy import *
rf(10,6)
# Out:
# 3603600

# %%
from sympy import *
n=symbols("n")
rf(n,5)
# Out:
# n*(n + 1)*(n + 2)*(n + 3)*(n + 4)

# %%
from sympy import *
n=symbols("n")
rf(n,-5)
# Out:
# 1/((n - 5)*(n - 4)*(n - 3)*(n - 2)*(n - 1))

# %%
from sympy import *
from sympy.plotting import *
x=symbols("x")
plot(rf(x,Rational(1,2)),(x,-0.5,4),ylim=(-1.5,2))
# Out:
# D:\Program Files\Python3.7\lib\site-packages\sympy\plotting\plot.py:1333: RuntimeWarning: invalid value encountered in double_scalars
#   cos_theta = dot_product / (vector_a_norm * vector_b_norm)

# %%
from sympy import *
from sympy.plotting import *
x,y,z=symbols("x y z")
plot3d(abs(rf(x+I*y,2)),(x,-2,2),(y,-2,2),ylim=(-1.5,2))

# %%
from sympy import *
rf(x,Rational(1,2)).series(x0=0,n=3).simplify()
# Out:
# sqrt(pi)*x - 2*sqrt(pi)*x**2*log(2) + O(x**3)

# %%
from sympy import *
rf(x,Rational(1,2)).series(x0=oo,n=3).simplify()
# fail
# Out:
# ---------------------------------------------------------------------------
# PoleError                                 Traceback (most recent call last)
# <ipython-input-20-b6c699e783d6> in <module>
#       1 from sympy import *
# ----> 2 rf(x,Rational(1,2)).series(x0=oo,n=3).simplify()
#       3 # fail
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\core\expr.py in series(self, x, x0, n, dir, logx)
#    2808         if x0 in [S.Infinity, S.NegativeInfinity]:
#    2809             sgn = 1 if x0 is S.Infinity else -1
# -> 2810             s = self.subs(x, sgn/x).series(x, n=n, dir='+')
#    2811             if n is None:
#    2812                 return (si.subs(x, sgn/x) for si in s)
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\core\expr.py in series(self, x, x0, n, dir, logx)
#    2834             # replace x with an x that has a positive assumption
#    2835             xpos = Dummy('x', positive=True, finite=True)
# ...

# %%
from sympy import *
rf(x,-3).series(x0=1,n=4).simplify()
# Out:
# (21 - 66*x + 124*x**2 - 94*x**3 + 31*x**4 + O((x - 1)**4, (x, 1)))/(32*(x - 1))

# %% [markdown]
# ## Scope

# %% [markdown]
# ### Numerical Evaluation

# %%
from sympy import *
rf(2.4,8.5)
# Out:
# 2310224.67324071

# %%
from sympy import *
rf(0,1285)
# Out:
# 0

# %%
from sympy import *
rf(Rational(3,2),Rational(1,2)).simplify()
# Out:
# 2/sqrt(pi)

# %%
from sympy import *
rf(Rational(1,3),7).evalf(n=50)
# Out:
# 505.97165066300868770004572473708276177411979881116

# %%
from sympy import *
rf(1.011111111111000000000000000,8)
# Out:
# 41552.2758490878

# %%
from sympy import *
rf(2.+5*I,8*I).evalf()
# Out:
# 2.1386822918681e-6 - 1.421873771171e-5*I

# %%
from sympy import *

# %%
from sympy import *

# %% [markdown]
# ### Specific Values

# %%
from sympy import *
Array([1,2,3,4,5]).applyfunc(lambda x:rf(x,2))
# Out:
# [2, 6, 12, 20, 30]

# %%
from sympy import *
rf(4,n).rewrite(gamma)
# Out:
# gamma(n + 4)/6

# %%
from sympy import *
rf(0,1)
# Out:
# 0

# %%
from sympy import *
rf(x,4)
# Out:
# x*(x + 1)*(x + 2)*(x + 3)

# %%
from sympy import *

# %%
from sympy import *

# %%
from sympy import *

# %%
from sympy import *

# %%
from sympy import *

# %% [markdown]
# ### Visualization

# %%
from sympy import *
from sympy.plotting import *
plot(rf(x,1),rf(x,2),rf(x,3),rf(x,4),(x,-4,4),ylim=(-30,50))

# %%
from sympy import *
from sympy.plotting import *
n=symbols("n")
plot(rf(1,n),rf(2,n),rf(3,n),rf(4,n),(n,0,4),ylim=(0,150))

# %%
from sympy import *

# %%
from sympy import *

# %%
from sympy import *

# %%
from sympy import *

# %% [markdown]
# ## Function Properties

# %%
from sympy import *
z=symbols("z")
Eq(rf(conjugate(z),2),conjugate(rf(z,2)))
# Out:
# True

# %% [markdown]
# ### Differentiation

# %%
from sympy import *
a=symbols("a")
rf(a,n).diff(a).simplify()
# Out:
# Derivative(RisingFactorial(a, n), a)

# %%
from sympy import *
n=symbols("n")
rf(a,n).diff(n).simplify()
# Out:
# Derivative(RisingFactorial(a, n), n)

# %% [markdown]
# ### Integration

# %% [markdown]
# ### Series Expansions

# %%
from sympy import *
rf(n,x).series(x=x,x0=0,n=3).simplify()
# Out:
# 1 + x*Subs(Derivative(RisingFactorial(n, _x), _x), _x, 0) + x**2*Subs(Derivative(RisingFactorial(n, _x), (_x, 2)), _x, 0)/2 + O(x**3)

# %%
from sympy import *
rf(n,x).series(x=x,x0=oo,n=1).simplify()
# Out:
# ---------------------------------------------------------------------------
# PoleError                                 Traceback (most recent call last)
# <ipython-input-60-921c648a2d8f> in <module>
#       1 from sympy import *
# ----> 2 rf(n,x).series(x=x,x0=oo,n=1).simplify()
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\core\expr.py in series(self, x, x0, n, dir, logx)
#    2808         if x0 in [S.Infinity, S.NegativeInfinity]:
#    2809             sgn = 1 if x0 is S.Infinity else -1
# -> 2810             s = self.subs(x, sgn/x).series(x, n=n, dir='+')
#    2811             if n is None:
#    2812                 return (si.subs(x, sgn/x) for si in s)
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\core\expr.py in series(self, x, x0, n, dir, logx)
#    2834             # replace x with an x that has a positive assumption
#    2835             xpos = Dummy('x', positive=True, finite=True)
# ...

# %% [markdown]
# ### Integral Transforms

# %% [markdown]
# ### Function Identities and Simplifications

# %%
from sympy import *
a,n,m=symbols("a n m")
Eq(rf(a,n),rf(a,m)*rf(a+m,n-m)).simplify()
# Out:
# True

# %%
from sympy import *
a,n,m=symbols("a n m")
Eq(rf(a,n),(a+n-1)/(a-1)*rf(a-1,n)).simplify()
# Out:
# True

# %%
from sympy import *
a,n,m=symbols("a n m")
Eq(rf(a,n),a/(a+n)*rf(a+1,n)).simplify()
# Out:
# True

# %% [markdown]
# ### Generalizations & Extensions

# %%
from sympy import *
rf(oo,2)
# Out:
# oo

# %%
from sympy import *
Array([2,3,5,7,11]).applyfunc(lambda x:rf(x,3))
# Out:
# [24, 60, 210, 504, 1716]

# %% [markdown]
# ## Applications

# %%
from sympy import *
a,k,z=symbols("a k z")
summation(rf(a,k)*z**k/factorial(k),(k,0,oo))
# Out:
# Piecewise(((1 - z)**(-a), ((re(a) >= 1) & (Abs(z) < 1)) | ((Abs(z) <= 1) & (re(a) < 0)) | (Ne(z, 1) & (re(a) >= 0) & (Abs(z) <= 1) & (re(a) < 1))), (Sum(z**k*RisingFactorial(a, k)/factorial(k), (k, 0, oo)), True))

# %%
from sympy import *
a,b,k,z=symbols("a b k z")
summation(1/rf(b,k)*z**k/factorial(k),(k,0,oo))
# Out:
# z**(1/2 - b/2)*besseli(b - 1, 2*sqrt(z))*gamma(b)

# %%
from sympy import *
a,b,k,z=symbols("a b k z")
summation(rf(a,-k)*rf(b,-k)*z**k/factorial(k),(k,0,oo))
# Out:
# hyper((), (1 - a, 1 - b), z)

# %%
from sympy import *
from sympy.plotting import *
plot(*Array(range(0,5)).applyfunc(lambda k:rf(x,k)),(x,-6,6),ylim=(-50,90))

# %%
from sympy import *
from sympy.plotting import *
k,x=symbols("k x")
plot(*Array(range(0,5)).applyfunc(lambda k:rf(k,x)),(x,-6,2))
# old bug
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Program Files\Python3.7\lib\site-packages\sympy\core\evalf.py in evalf(x, prec, options)
#    1310     try:
# -> 1311         rf = evalf_table[x.func]
#    1312         r = rf(x, prec, options)
#
# KeyError: factorial
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# D:\Program Files\Python3.7\lib\site-packages\sympy\plotting\experimental_lambdify.py in __call__(self, args, kwargs)
#     194             #The result can be sympy.Float. Hence wrap it with complex type.
# --> 195             result = complex(self.lambda_func(args))
#     196             if abs(result.imag) > 1e-7 * abs(result):
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\plotting\experimental_lambdify.py in __call__(self, *args, **kwargs)
# ...

# %%
from sympy import *

# %%
from sympy import *

# %%
from sympy import *

# %% [markdown]
# ## Properties & Relations

# %%
from sympy import *
(gamma(a)*rf(a,k)).simplify()
# Out:
# gamma(a + k)

# %%
from sympy import *
(rf(n,k)).rewrite(gamma)
# Out:
# gamma(k + n)/gamma(n)

# %%
from sympy import *
summation(rf(n,k)*x**k,(k,0,n)).rewrite(gamma).simplify()
# Out:
# Sum(x**k*gamma(k + n), (k, 0, n))/gamma(n)

# %%
from sympy import *
summation(1/rf(n,k)**2*z**k,(k,0,oo))
# Out:
# hyper((1,), (n, n), z)

# %%
from sympy import *
summation(1/rf(2*k,k),(k,1,oo))
# Out:
# hyper((1, 3/2), (4/3, 5/3), 4/27)/2

# %%
from sympy import *
p=Function("p")
rsolve(n*p(n)-p(n+1),p(n))
# failed

# %%
from sympy import *
-exp(-1/x)/x*expint(n,-1/x).series(x=x,x0=0,n=4)
# Out:
# ---------------------------------------------------------------------------
# PoleError                                 Traceback (most recent call last)
# <ipython-input-107-4f87fbec2b5c> in <module>
#       1 from sympy import *
# ----> 2 -exp(-1/x)/x*expint(n,-1/x).series(x=x,x0=0,n=4)
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\core\expr.py in series(self, x, x0, n, dir, logx)
#    2834             # replace x with an x that has a positive assumption
#    2835             xpos = Dummy('x', positive=True, finite=True)
# -> 2836             rv = self.subs(x, xpos).series(xpos, x0, n, dir, logx=logx)
#    2837             if n is None:
#    2838                 return (s.subs(xpos, x) for s in rv)
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\core\expr.py in series(self, x, x0, n, dir, logx)
#    2841
#    2842         if n is not None:  # nseries handling
# -> 2843             s1 = self._eval_nseries(x, n=n, logx=logx)
# ...

# %%
from sympy import *
hyper([n,1],[],x).series(x=x,n=5).simplify()
# Out:
# 1 + n*x + n*x**2*(n + 1) + n*x**3*(n**2 + 3*n + 2) + n*x**4*(n**3 + 6*n**2 + 11*n + 6) + O(x**5)

# %% [markdown]
# ## Possible Issues

# %%
from sympy import *
rf(10.**100,10**99)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-112-0cc5172863b3> in <module>
#       1 from sympy import *
# ----> 2 rf(10.**100,10**99)
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      92             def wrapper(*args, **kwargs):
#      93                 try:
# ---> 94                     retval = cfunc(*args, **kwargs)
#      95                 except TypeError:
#      96                     retval = func(*args, **kwargs)
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\core\function.py in __new__(cls, *args, **options)
#     471
#     472         evaluate = options.get('evaluate', global_evaluate[0])
# --> 473         result = super(Function, cls).__new__(cls, *args, **options)
#     474         if evaluate and isinstance(result, cls) and result.args:
# ...

# %%
from sympy import *
rf(10.**6,10.**5)
# Out:
# 3.05342583963934e+602102

# %%
from sympy import *
rf(-5,-3)
# Out:
# -1/336

# %%
from sympy import *
rf(-5,-3).evalf()
# Out:
# -0.00297619047619048

# %%
from sympy import *
rf(-5*.0000001,-3*.00000000001)
# Out:
# 0.999940003617099

# %%
from sympy import *
#n,m=symbols("n m",Integer=True)
#Q.is_true(n>0) and Q.is_true(m>0)
refine(rf(-n,-m)).rewrite(gamma)
# Out:
# gamma(-m - n)/gamma(-n)

# %% [markdown]
# ## Neat Example

# %%
from sympy import *
summation(binomial(6,k)*rf(x,k)*rf(y,6-k),(k,0,6)).factor()
# Out:
# (x + y)*(x + y + 1)*(x + y + 2)*(x + y + 3)*(x + y + 4)*(x + y + 5)

# %%
from sympy import *
rf(x+y,6)
# Out:
# (x + y)*(x + y + 1)*(x + y + 2)*(x + y + 3)*(x + y + 4)*(x + y + 5)
