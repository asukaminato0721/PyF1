# %% [markdown]
# # Examples

# %%
from sympy.abc import *
from sympy import *

# %% [markdown]
# ## Basic Examples

# %%
limit(sin(x)/x, x , 0)
# Out:
# 1

# %%
limit((1 + sinh(x))/exp(x), x , oo)
# Out:
# 1/2

# %%
plot((1 + sinh(x))/exp(x), 1/2,-9, (x, 0, 10),ylim=(0,1),axis_center=(0,0))

# %%
limit(Abs(x)/x, x , 0, "+")
# Out:
# 1

# %%
limit(Abs(x)/x, x , 0, "-")
# Out:
# -1

# %%
limit(Abs(x)/x, x , 0)
# Out:
# 1

# %%
plot(Abs(x)/x, (x, -1, 1))

# %%
limit(sin(x), x ,pi/2)
# Out:
# 1

# %%
limit(x/(x - 2 *a), x , a)
# Out:
# -1

# %%
limit(3* x**2/(x**2 - 2), x , -oo)
# Out:
# 3

# %%
limit(
    limit(Abs(x) *tan(y)**2,( x , 0)), 
    (y , pi/2)
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-b725a14ad99c> in <module>
#       1 limit(
# ----> 2     limit(Abs(x) *tan(y)**2,( x , 0)),
#       3     (y , pi/2)
#       4 )
#
# TypeError: limit() missing 1 required positional argument: 'z0'

# %%
limit( a* x**2 + 4 *x + 7, x , 1)
# Out:
# a + 11

# %%
limit(1/(x - 2)**2, x , 2)
# Out:
# oo

# %%
plot(1/(x - 2)**2, (x, 1, 3), 
    )

# %%
limit(sqrt(x - 1)/x, x , 1)
# Out:
# 0

# %%
limit(3 *(x**a - a *x + a - 1)/(x - 1)**2, x , 1)
# Out:
# 3*a**2/2 - 3*a/2

# %%
plot((x - 3)/(sqrt(x) - 3), (x, 8, 10),ylim=(-400,400))

# %%
limit(sin(2* x)/sin(x), x , pi)
# Out:
# -2

# %%
limit((tan(x) - x)/x**3, x , 0)
# Out:
# 1/3

# %%
limit(tan(x), x , pi/2, "-")
# Out:
# oo

# %%
plot(tan(x), (x, 0, pi),ylim=(-6,6))

# %%
limit(sin(1/x), x , 0)
# Out:
# AccumBounds(-1, 1)

# %%
plot(sin(1/x), (x, -.1, .1))

# %%
limit(x**n *exp(-x**-2), x , 0)
# Out:
# 0

# %%
limit((25**x - 5**x)/(4**x - 2**x), x , 0) . simplify()
# Out:
# log(5)/log(2)

# %%
limit((1 + sin(5* x))**cot(x), x , 0)
# Out:
# exp(5)

# %%
limit(x* log(x**2), x , 0)
# Out:
# 0

# %%
limit(log(x)/x, x , 0)
# Out:
# -oo

# %%
limit((x**a - 1)/a, a , 0)
# Out:
# log(x)

# %%
limit(sin(x) + log(x - a)/log(E**x - E**a), x , a)
# Out:
# sin(a) + 1

# %%
Array(limit(j, z , -1) for j in [sqrt(z),log(z)])
# Out:
# [I, I*pi]

# %%
limit(1/x, x , oo)
# Out:
# 0

# %%
limit(sqrt(x**2 + a* x) - sqrt(x**2 + b*x), x ,oo)
# Out:
# a/2 - b/2

# %%
limit(a* x**2/(b* x**2 - x), x , -oo)
# Out:
# a/b

# %%
limit(sin(x), x , oo)
# Out:
# AccumBounds(-1, 1)

# %%
limit(atan(x**3 - x), x , -oo)
# Out:
# -pi/2

# %%
plot(atan(x**3 - x), -pi/2, pi/2, (x, -5, 5))

# %%
limit(x**2 + x* sin(x**2), x , oo)
# Out:
# oo

# %%
plot(x**2 + x *sin(x**2), (x, 0, 10))

# %%
limit(exp(x) * (exp(1/x - exp(-x)) - exp(1/x)), x , oo)
# Out:
# -1

# %%
plot(exp(x) * (exp(1/x - exp(-x)) - exp(1/x)), -1, (x, 1, 20))

# %%
limit(x**(1/x), x , oo)
# Out:
# 1

# %%
plot(x**(1/x), 1, (x, 0, 40)
     )

# %%
limit((1 + a/x)**(b* x), x , oo)
# Out:
# exp(a*b)

# %%
limit(log(x)/sqrt(x), x , -oo)
# Out:
# 0

# %%
limit(exp(
    exp(-x/(1 + exp(-x))))* exp(-x/(1 + exp(-x)/(1 + exp(-x)))) *exp(
     exp(-x + exp(-x/(1 + exp(-x)))))/(exp(-x/(1 + exp(-x))))**2 - 
  exp(x) + x, x , oo)
# Out:
# 2

# %%
limit((log(log(x) + log(log(x))) - log(log(x)))/
   log(log(x) + log(log(log(x)))) *log(x), x ,oo)
# Out:
# 1

# %%
limit(exp(
  log(log(x + exp(log(x) *log(log(x)))))/
   log(log(log(exp(x) + x + log(x))))), x , oo)
# Out:
# E

# %%
limit(gamma(z), z , -1, "+")
# Out:
# zoo

# %%
limit(gamma(x + 1)**(1/x)/x, x , oo)
# Out:
# exp(-1)

# %%
plot(gamma(x + 1)**(1/x)/x, 1/E,-9, (x, 0, 30),ylim=(0,1.2))

# %%
limit(gamma(x + 1/2)/gamma(x)/sqrt(x), x , oo)
# Out:
# 1

# %%
plot(gamma(x + 1/2)/gamma(x)/x, 1/sqrt(x),-1, (x, 0, 10), 
ylim=(0, 1.2))

# %%
limit(besseli(1, 3 *x)/(x *besseli(1, x)**3), x , oo)
# Out:
# ---------------------------------------------------------------------------
# PoleError                                 Traceback (most recent call last)
# D:\Program Files\Python3.7\lib\site-packages\sympy\series\limits.py in doit(self, **hints)
#     260             else:
# --> 261                 r = gruntz(e, z, z0, dir)
#     262             if r is S.NaN or l is S.NaN:
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\series\gruntz.py in gruntz(e, z, z0, dir)
#     670     try:
# --> 671         r = limitinf(e0, z)
#     672     except ValueError:
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      93                 try:
# ---> 94                     retval = cfunc(*args, **kwargs)
#      95                 except TypeError:
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\series\gruntz.py in limitinf(e, x, leadsimp)
#     434         x = p
# --> 435     c0, e0 = mrv_leadterm(e, x)
#     436     sig = sign(e0, x)
# ...

# %%
plot(besseli(1, 3 *x)/(x *besseli(1, x)**3), (2 *pi)/sqrt(3),-10, (x, 0, 
  10), ylim =(0, 20))

# %%
limit(fresnels(x)/x**3, x , 0)
# Out:
# pi/6

# %%
limit(erfc(x), x , -oo)
# Out:
# 2

# %%
plot(erfc(x), 2, (x, -5, 5))

# %%
limit(Ci(x)/log(x**a), x , 0)
# Out:
# 1/a

# %%
from sympy.plotting import *
plot3d(atan(y**2/(x**2 + x**3)), (x, -1, 1), (y, -1, 1))
# Out:
# <string>:1: RuntimeWarning: divide by zero encountered in true_divide
# ---------------------------------------------------------------------------
# FloatingPointError                        Traceback (most recent call last)
# D:\Program Files\Python3.7\lib\site-packages\sympy\plotting\experimental_lambdify.py in __call__(self, *args)
#     118             temp_args = (np.array(a, dtype=np.complex) for a in args)
# --> 119             results = self.vector_func(*temp_args)
#     120             results = np.ma.masked_where(
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\plotting\experimental_lambdify.py in __call__(self, *args, **kwargs)
#     314     def __call__(self, *args, **kwargs):
# --> 315         return self.lambda_func(*args, **kwargs)
#     316
#
# <string> in <lambda>(x0, x1)
#
# FloatingPointError: invalid value encountered in true_divide
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
a=symbols("x",positive=True)
limit(x**a, x , oo)
# Out:
# oo

# %%
limit(1/x, x , 0,  "+")
# Out:
# oo

# %%
limit(1/x, x , 0,  "-")
# Out:
# -oo

# %%
limit(frac(x**2)* sin(x), x , 2,  "-")
# Out:
# 0

# %%
limit(frac(x**2)* sin(x), x , 2,  "+")
# Out:
# 0

# %%
plot(frac(x**2) *sin(x), (x, 0, 7))

# %%
limit(tan(x), x ,pi/2, "-")
# Out:
# oo

# %%
limit(tan(x), x ,pi/2, "+")
# Out:
# -oo

# %%
n=symbols("n",positive=True)
limit(x**n, x , 0)
# Out:
# 0

# %%
f = (x**2 + 3)/(2 *x + 1)
m = limit(f/x, x , oo)
b = limit(f - m *x, x , oo)
plot(f, m* x + b, (x, 0, 10))

# %%
f= (3**(1/x) - 3**(-1/x))/(3**(1/x) + 3**(-1/x))
limit(f, x , 0,"-")
# Out:
# -1

# %%
limit(f, x , 0, "+")
# Out:
# 1

# %%
plot(f,(x, -3, 3))
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# D:\Program Files\Python3.7\lib\site-packages\sympy\plotting\experimental_lambdify.py in __call__(self, args, kwargs)
#     194             #The result can be sympy.Float. Hence wrap it with complex type.
# --> 195             result = complex(self.lambda_func(args))
#     196             if abs(result.imag) > 1e-7 * abs(result):
#
# D:\Program Files\Python3.7\lib\site-packages\sympy\plotting\experimental_lambdify.py in __call__(self, *args, **kwargs)
#     314     def __call__(self, *args, **kwargs):
# --> 315         return self.lambda_func(*args, **kwargs)
#     316
#
# <string> in <lambda>(x0)
#
# OverflowError: complex exponentiation
#
# During handling of the above exception, another exception occurred:
#
# OverflowError                             Traceback (most recent call last)
# ...

# %%
limit((1 + 1/x)**x, x , oo)
# Out:
# E

# %%
limit((1 + x)**(1/x), x , 0)
# Out:
# E

# %%
limit((2**(4 *x + 1)* gamma(x + 1)**4)/((2* x + 1) *gamma(2* x + 1)**2), 
 x , oo)
# Out:
# pi

# %%
limit(zeta(x) - 1/(x - 1), x , 1).simplify()
# Out:
# Limit(((x - 1)*zeta(x) - 1)/(x - 1), x, 1)

# %%
limit(Ei(log(1 + x)) + log(1 - 1/x) - 
 Ei(log(x)) - I* pi, x , 0, "-")
# Out:
# EulerGamma

# %%
integrate(1/x**2, (x, 1, a))
# Out:
# 1 - 1/a

# %%
limit(integrate(1/x**2, (x, 1, a)), a , oo)
# Out:
# 1

# %%
limit(x *sin(1/x), x , 0)
# Out:
# 0

# %%
plot(x *sin(1/x), Abs(x), -Abs(x), (x, -1, 1))

# %%
limit(sin(x)/x, x , oo)
# Out:
# 0

# %%
limit(1/x, x ,oo)
# Out:
# 0

# %%
plot(sin(x)/x, 1/x, -1/x, (x, 0, 50),ylim=(-0.35,0.35))

# %%
n=symbols("n",integer=True)
limit(tan(x), x , pi/2 + n* pi, "-")
# Out:
# oo

# %%
n=symbols("n",integer=True)
limit(tan(x), x , pi/2 + n* pi, "+")
# Out:
# -oo

# %%
plot(tan(x), (x, -2 *pi, 2 *pi), ylim=(-6,6)

    )

# %%
f= erf(x)
g= x
limit(f.diff(x)/g.diff(x),x,0)
# Out:
# 2/sqrt(pi)

# %%
limit(log(1 - (log(exp(z)/z - 1) + log(z))/z)/z, z , 100)
# Out:
# log(-log(-1 + exp(100)/100)/100 - log(10)/50 + 1)/100
